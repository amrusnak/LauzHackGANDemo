# %% [markdown]
# # Generative Adversarial Networks: Synthetic Data For Fun and Profit
# ### Written by: Alex Rusnak

# %% [markdown]
# ### This notebook contains all the building blocks for a simple GAN, and some examples of how to use it. Though these are toy examples, they illustrate some important concepts about how to use this type of network.

# %%
# Import requirements

import os
import torch
from torch import nn
from torch import optim
from torch.nn import init
import torch.nn.functional as F
import torch.utils.data
from torch.autograd import Variable
import torchvision as tv
from torchvision import transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import seaborn as sns
from time import time
import numpy as np
from PIL import Image
import pandas as pd
import argparse
import cv2
import gc

#Check to make sure GPU is available
# !nvidia-smi
# Out:
# Wed Dec  8 12:05:05 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.63.01    Driver Version: 470.63.01    CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:01:00.0  On |                  N/A |
# | N/A   48C    P3    30W /  N/A |   1131MiB / 16125MiB |      8%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A       957      G   /usr/lib/xorg/Xorg                635MiB |
# |    0   N/A  N/A      1512      G   cinnamon                          119MiB |
# |    0   N/A  N/A      2257      G   ...AAAAAAAAA= --shared-files      102MiB |
# |    0   N/A  N/A      5685      G   /usr/lib/firefox/firefox          157MiB |
# |    0   N/A  N/A      6509      G   .../debug.log --shared-files       24MiB |
# |    0   N/A  N/A      8359      G   /usr/lib/firefox/firefox            3MiB |
# |    0   N/A  N/A     30103      G   ...token=4884707744632860660       83MiB |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ### Below is the beginning of the code for a very simple deep convolutional GAN, I usually use this as a framework to test components for bigger networks. But because it is so lightweight, it is perfect for this presentation!

# %%
# Define the generator class for the network

class Generator(nn.Module):
        def __init__(self, latent_dim=100, batchnorm=True, use_attn=False, size=160, out_chan=3):

            #init 
            super(Generator, self).__init__()
            self.latent_dim = latent_dim
            self.batchnorm = batchnorm
            self.use_attn = use_attn
            self.out_chan = out_chan
            self.layer_size = int(size/2/2)
            self._init_modules()
            
        def _init_modules(self):

            #project input
            self.linear1 = nn.Linear(self.latent_dim, 256*self.layer_size*self.layer_size, bias=False)
            self.bn1d1 = nn.BatchNorm1d(256*self.layer_size*self.layer_size) if self.batchnorm else None
            
            # Using leaky relu as activation layer
            self.leaky_relu = nn.LeakyReLU()

            #regular convolutional layer
            self.conv1 = nn.Conv2d(
                in_channels=256, 
                out_channels=128, 
                kernel_size=5, 
                stride=1,
                padding=2,
                bias=False)
            
            # Defines a batchnorm layer if you flag for it
            self.bn2d1 = nn.BatchNorm2d(128) if self.batchnorm else None
            
            # Defines 2 self attention layers if you flag for it
            if self.use_attn:
                self.attn = SelfAttention(128)
                self.attn = SelfAttention(128)
                
            # Notice this is a transpose convolution - it is upscaling the data    
            self.conv2 = nn.ConvTranspose2d(
                in_channels=128, 
                out_channels=64, 
                kernel_size=4, 
                stride=2,
                padding=1,
                bias=False)
            
            # Using dropout to prevent overfitting
            self.dropout_2d = nn.Dropout2d(0.1)
            
            # Defines a batchnorm layer if you flag for it
            self.bn2d2 = nn.BatchNorm2d(64) if self.batchnorm else None
            
            #Another transpose convolution
            self.conv3 = nn.ConvTranspose2d(
                in_channels=64, 
                out_channels=self.out_chan, 
                kernel_size=4, 
                stride=2,
                padding=1,
                bias=False)
            
            # Output Activation
            self.tanh = nn.Tanh()
            
        def forward(self, input_tensor):

            # Map latent vectors to samples
            
            intermediate = self.linear1(input_tensor)
            intermediate = self.bn1d1(intermediate)
            intermediate = self.leaky_relu(intermediate)
           
            intermediate = intermediate.view((-1, 256, self.layer_size, self.layer_size))
                
            intermediate = self.conv1(intermediate)
            
            if self.batchnorm:
                intermediate = self.bn2d1(intermediate)
                
            intermediate = self.leaky_relu(intermediate)
            
            intermediate = self.dropout_2d(intermediate)
            
            if self.use_attn:
                intermediate = self.leaky_relu(self.attn(intermediate))
            
            intermediate = self.conv2(intermediate)
            
            if self.batchnorm:
                intermediate = self.bn2d2(intermediate)
                
            intermediate = self.dropout_2d(intermediate)
            
            intermediate = self.leaky_relu(intermediate)
            
            intermediate = self.conv3(intermediate)
            
            output_tensor = self.tanh(intermediate)
            
            return output_tensor

# %%
# Defining the discriminator for the network

class Discriminator(nn.Module):

    def __init__(self, use_attn=False, size=160, in_chan=3):
        super(Discriminator, self).__init__()
        
        # init
        self.use_attn = use_attn
        self.layer_size = int(size/2/2)
        self.in_chan = in_chan
        self._init_modules()
        
    def _init_modules(self):
        
        # Notice this only uses regular convolutional layers (no upscaling)
        self.conv1 = nn.Conv2d(
            in_channels=self.in_chan,
            out_channels=64,
            kernel_size=5,
            stride=2,
            padding=2,
            bias=True)
        
        self.bn2d1 = nn.BatchNorm2d(64)
        self.leaky_relu = nn.LeakyReLU()
        
        # Using dropout to prevent overfitting
        self.dropout_2d = nn.Dropout2d(0.3)

        self.conv2 = nn.Conv2d(
            in_channels=64,
            out_channels=128,
            kernel_size=5,
            stride=2,
            padding=2,
            bias=True)
        
        self.bn2d2 = nn.BatchNorm2d(128)
       
        # Attention if you want it
        if self.use_attn:
            self.attn = SelfAttention(128)
            
        self.linear1 = nn.Linear(128*self.layer_size*self.layer_size, 1, bias=True)
        
        # Sigmoid output activation because this is a binary classifier
        self.sigmoid = nn.Sigmoid()

    def forward(self, input_tensor):

        intermediate = self.conv1(input_tensor)
        intermediate = self.bn2d1(intermediate)
        intermediate = self.leaky_relu(intermediate)
        intermediate = self.dropout_2d(intermediate)

        intermediate = self.conv2(intermediate)
        intermediate = self.bn2d2(intermediate)
        intermediate = self.leaky_relu(intermediate)
        intermediate = self.dropout_2d(intermediate)
        
        if self.use_attn:
                intermediate = self.leaky_relu(self.attn(intermediate))
                
        intermediate = intermediate.view((-1, 128*self.layer_size*self.layer_size))
        
        intermediate = self.linear1(intermediate)
        output_tensor = self.sigmoid(intermediate)

        return output_tensor

# %%
# Defining the whole network
class DCGAN():

    def __init__(self, latent_dim, noise_fn, dataloader, 
            batch_size=32, device='cpu', lr_d=1e-3, lr_g=2e-4, use_attn=False, chans=3, size=160):

        self.generator = Generator(latent_dim, use_attn=use_attn, out_chan=chans, size=size).to(device)
        self.discriminator = Discriminator(use_attn=use_attn, in_chan=chans, size=size).to(device)
        
        self.batch_size = batch_size
        self.dataloader = dataloader
        
        self.device = device
        
        self.noise_fn = noise_fn
        self.criterion = nn.BCELoss()

        self.optim_g = optim.Adam(self.generator.parameters(), lr=lr_g, betas=(0.5, 0.999))
        self.optim_d = optim.Adam(self.discriminator.parameters(), lr=lr_d, betas=((0.5, 0.999)))

        self.target_ones = torch.ones((batch_size, 1), device=device)
        self.target_zeros = torch.zeros((batch_size, 1), device=device)
        
    # Saves the generator and discriminator when called
    def saveState(self, epoch=0, chkpt='test'):
        
        print('Saving Checkpoint...')
        torch.save({
            'epoch': epoch,
            'model_state_dict': self.generator.state_dict(),
            'optimizer_state_dict': self.optim_g.state_dict()
            }, "checkpoints/generator/" + chkpt + "G")

        torch.save({
            'epoch': epoch,
            'model_state_dict': self.discriminator.state_dict(),
            'optimizer_state_dict': self.optim_d.state_dict()
            }, "checkpoints/discriminator/" + chkpt + "D")
    
    # Loads the generator and discriminator when called
    def loadState(self, chkpt):

        checkpointG = torch.load("checkpoints/generator/" + chkpt + "G")
        self.generator.load_state_dict(checkpointG['model_state_dict'])
        self.optim_g.load_state_dict(checkpointG['optimizer_state_dict'])

        checkpointD = torch.load("checkpoints/discriminator/" + chkpt + "D")
        self.discriminator.load_state_dict(checkpointD['model_state_dict'])
        self.optim_d.load_state_dict(checkpointD['optimizer_state_dict'])

        #print(self.generator)
        #print(self.discriminator)

        return checkpointD['epoch']
    
    # Generates new samples from the generator when called, can take a latent vector as input
    def generate_samples(self, latent_vec=None, num=None):

        num = self.batch_size if num is None else num
        
        # Generates a latent vector if one is not provided
        latent_vec = self.noise_fn(num) if latent_vec is None else latent_vec

        with torch.no_grad():
            samples = self.generator(latent_vec)

        samples = samples.cpu()
        latent_vec = latent_vec.cpu()
        # Returns samples (new images) and the latent vector corresponding to those images
        return samples, latent_vec
    
    # Training function for the generator. 
    # Reminder the two networks train in sequence, not concurrently
    def train_step_generator(self):

        self.generator.zero_grad()
        
        latent_vec = self.noise_fn(self.batch_size)
        
        # Generates images
        generated = self.generator(latent_vec)
        
        # Uses the discriminator to classify whether generated images are real or fake
        classifications = self.discriminator(generated)
        
        # Loss function on classifications
        loss = self.criterion(classifications, self.target_ones)

        loss.backward()
        self.optim_g.step()
        return loss.item()
    
    # Training function for the discriminator
    def train_step_discriminator(self, real_samples):
        
        self.discriminator.zero_grad()
        
        # Discriminates on only REAL images and then finds loss for those predictions
        pred_real = self.discriminator(real_samples)
        loss_real = self.criterion(pred_real, self.target_ones)
        
        latent_vec = self.noise_fn(self.batch_size)

        with torch.no_grad():
            # uses the generator to create new FAKE images
            fake_samples = self.generator(latent_vec)
            
        # Discriminates on only FAKE images and then finds loss for those predictions
        pred_fake = self.discriminator(fake_samples)
        loss_fake = self.criterion(pred_fake, self.target_zeros)
        
        # Loss is average of two losses 
        loss = (loss_real + loss_fake) / 2

        loss.backward()

        self.optim_d.step()

        return loss_real.item(), loss_fake.item()
    
    # Trains one epoch (self explanatory)
    def train_epoch(self, print_frequency=10, max_steps=0):

        loss_g_running, loss_d_real_running, loss_d_fake_running = 0, 0, 0

        for batch, (real_samples, _) in enumerate(self.dataloader):
            
            real_samples = real_samples.to(self.device)
            
            # Train D step for batch
            if (len(real_samples) == 32):
                ldr_, ldf_ = self.train_step_discriminator(real_samples)

            loss_d_real_running  += ldr_
            loss_d_fake_running  += ldf_
            
            # Train G step for batch
            loss_g_running += self.train_step_generator()
            
            # Prints losses
            if print_frequency and (batch+1) % print_frequency ==0:
                    
                    print(f"{batch+1}/{len(self.dataloader)}:"
                      f" G={loss_g_running / (batch+1):.3f},"
                      f" Dr={loss_d_real_running / (batch+1):.3f},"
                      f" Df={loss_d_fake_running / (batch+1):.3f}",
                      end='\r',
                      flush=True)
                 

            if max_steps and batch == max_steps:
                break

        if print_frequency:
            print()
        
        loss_g_running /= batch
        loss_d_real_running /= batch
        loss_d_fake_running /= batch
        
        # Returns avg losses for epoch
        return [loss_g_running, loss_d_real_running, loss_d_fake_running]

# %%
# Attention Layer - beyond the scope of this presentation, but useful!
def init_conv(conv, glu=True):
    init.xavier_uniform_(conv.weight)
    if conv.bias is not None:
        conv.bias.data.zero_()

class SelfAttention(nn.Module):
    """ Self attention Layer"""
    def __init__(self,in_dim,activation=F.relu):
        super(SelfAttention,self).__init__()
        self.chanel_in = in_dim
        self.activation = activation
        
        self.query_conv = nn.Conv2d(in_channels = in_dim , out_channels = in_dim//8 , kernel_size= 1)
        self.key_conv = nn.Conv2d(in_channels = in_dim , out_channels = in_dim//8 , kernel_size= 1)
        self.value_conv = nn.Conv2d(in_channels = in_dim , out_channels = in_dim , kernel_size= 1)
        self.gamma = nn.Parameter(torch.zeros(1))

        self.softmax  = nn.Softmax(dim=-1) #

        init_conv(self.query_conv)
        init_conv(self.key_conv)
        init_conv(self.value_conv)
        
    def forward(self,x):
        """
            inputs :
                x : input feature maps( B X C X W X H)
            returns :
                out : self attention value + input feature 
                attention: B X N X N (N is Width*Height)
        """
        m_batchsize,C,width ,height = x.size()
        proj_query  = self.query_conv(x).view(m_batchsize,-1,width*height).permute(0,2,1) # B X CX(N)
        proj_key =  self.key_conv(x).view(m_batchsize,-1,width*height) # B X C x (*W*H)
        energy =  torch.bmm(proj_query,proj_key) # transpose check
        attention = self.softmax(energy) # BX (N) X (N) 
        proj_value = self.value_conv(x).view(m_batchsize,-1,width*height) # B X C X N

        out = torch.bmm(proj_value,attention.permute(0,2,1) )
        out = out.view(m_batchsize,C,width,height)
        
        out = self.gamma*out + x
        return out

# %%
# Main function for running the GAN
# Accepts a run type (load, train, or gen), a checkpoint name for the networks, epochs, 
# whether to use attention, a latent vector for gen mode only, and a modification to the 
# name of saved images to differentiate between gen runs

def runGAN(gen_or_train='train', chkpt_name='test', dataset='test', epochs=500, use_attn=False, size=160, latent_vec='', gen_name_mod='', folder_mod='Random/', bw=False):
        
        # Define important variables
        batch_size = 32
        epochs = int(epochs)
        latent_dim = 16
        
        # Create a loss tape for plotting
        loss_tape = [[0]*3]*epochs
        
        device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        #print(device)
        
        # Transforms on images
        if bw:
            channels = 1
            transform = tv.transforms.Compose([
                tv.transforms.Grayscale(num_output_channels=1),
                tv.transforms.ToTensor(),
                #tv.transforms.Normalize((0.5,), (0.5,))
                ])
        else:
            channels = 3
            transform = tv.transforms.Compose([
                #tv.transforms.Grayscale(num_output_channels=1),
                tv.transforms.ToTensor(),
                #tv.transforms.Normalize((0.5,), (0.5,))
                ])

        # Creates dataset
        dataset = ImageFolder(
            root=dataset,
            transform = transform)
        checkpointFrequency = 10
        # Creates dataloader from dataset
        dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, num_workers=2)
        
        # Define noise fucntion
        noise_fn = lambda x: torch.randn((x, latent_dim), device=device)
        
        # Creates the GAN with specifications
        gan = DCGAN(latent_dim, noise_fn, dataloader, device=device, batch_size=batch_size, use_attn=use_attn, chans=channels, size=size)
        
        # Loads GAN state and restarts training
        if(gen_or_train == 'load'):
            
            start = time()
            epoch = gan.loadState(chkpt_name) + 1
            
            for i in range(epoch, epochs):
                print(f"Epoch {i+1}; Elapsed Time = {int(time()- start)}s ")
                gan.train_epoch()
                if(i%checkpointFrequency==0):
                    gan.saveState(i+1, chkpt_name)

            images, latent_vec = gan.generate_samples() 
            images = images * -1
        
        # Trains fresh GAN 
        elif(gen_or_train == 'train'):
            
            start = time()

            for i in range(epochs): 
                print(f"Epoch {i+1}; Elapsed Time = {int(time()- start)}s ")
                loss_tape[i] = gan.train_epoch()
               
                if(i%checkpointFrequency==0):
                    gan.saveState(i, chkpt_name)
                
            images, latent_vec = gan.generate_samples() 
            images = images * -1
        
        # Generates new samples
        elif(gen_or_train == 'gen'):
            
            # Loads checkpoint
            epoch = gan.loadState(chkpt_name)
            
            # Generates samples from given latent vec
            if len(latent_vec)!=0:
                latent_vec = latent_vec.to(device)
                images, latent_vec = gan.generate_samples(latent_vec)
                
            # Generates samples from new / random latent vec
            else:
                images, latent_vec = gan.generate_samples()
    
            images = images * -1
            
             # Saves generated images
            for i in range(len(images)):
                
                img = transforms.ToPILImage()(images[i])
                img.save('data/GeneratedImages/' + folder_mod + gen_name_mod + '_'+ str(i) + '.png') 

        # Plots images
        ims = tv.utils.make_grid(images, normalize=True)

        plt.imshow(ims.numpy().transpose((1,2,0)))
        plt.show()
        
        del gan
        gc.collect()
        
        # returns loss_tape for plotting and last latent vector used to generate images
        return loss_tape, latent_vec

# %% [markdown]
# ## Time to train!
# ![alt text](data/PresentationImages/gan_training.png "Rivals")

# %%
#lt, lv = runGAN(chkpt_name='PorcelainDemo', dataset='data/RealImageData/', epochs=500, use_attn=True, bw=False, size=160)
# Out:
# Epoch 1; Elapsed Time = 0s
# 20/23: G=37.920, Dr=0.643, Df=0.665
# Saving Checkpoint...
# Epoch 2; Elapsed Time = 4s
# 20/23: G=10.198, Dr=0.154, Df=0.270
# Epoch 3; Elapsed Time = 8s
# 20/23: G=4.756, Dr=0.224, Df=0.275
# Epoch 4; Elapsed Time = 13s
# 20/23: G=2.271, Dr=0.392, Df=0.496
# Epoch 5; Elapsed Time = 17s
# 20/23: G=2.290, Dr=0.511, Df=0.441
# Epoch 6; Elapsed Time = 21s
# 20/23: G=2.089, Dr=0.306, Df=0.333
# Epoch 7; Elapsed Time = 26s
# 20/23: G=2.078, Dr=0.355, Df=0.390
# Epoch 8; Elapsed Time = 30s
# 20/23: G=2.210, Dr=0.604, Df=0.425
# Epoch 9; Elapsed Time = 34s
# 20/23: G=2.784, Dr=0.310, Df=0.311
# Epoch 10; Elapsed Time = 39s
# 20/23: G=2.183, Dr=0.481, Df=0.426
# Epoch 11; Elapsed Time = 43s
# 20/23: G=1.893, Dr=0.408, Df=0.428
# Saving Checkpoint...
# Epoch 12; Elapsed Time = 47s
# 20/23: G=2.195, Dr=0.393, Df=0.313
# Epoch 13; Elapsed Time = 52s
# 20/23: G=2.473, Dr=0.343, Df=0.314
# Epoch 14; Elapsed Time = 56s
# 20/23: G=2.213, Dr=0.411, Df=0.378
# Epoch 15; Elapsed Time = 61s
# 20/23: G=2.156, Dr=0.409, Df=0.323
# Epoch 16; Elapsed Time = 65s
# 20/23: G=2.317, Dr=0.400, Df=0.339
# Epoch 17; Elapsed Time = 69s
# 20/23: G=2.166, Dr=0.425, Df=0.351
# Epoch 18; Elapsed Time = 74s
# 20/23: G=2.497, Dr=0.361, Df=0.319
# Epoch 19; Elapsed Time = 78s
# 20/23: G=2.206, Dr=0.356, Df=0.314
# Epoch 20; Elapsed Time = 83s
# 20/23: G=2.428, Dr=0.381, Df=0.331
# Epoch 21; Elapsed Time = 87s
# 20/23: G=2.113, Dr=0.400, Df=0.441
# Saving Checkpoint...
# Epoch 22; Elapsed Time = 92s
# 20/23: G=2.228, Dr=0.501, Df=0.356
# Epoch 23; Elapsed Time = 96s
# 20/23: G=1.951, Dr=0.432, Df=0.366
# Epoch 24; Elapsed Time = 101s
# 20/23: G=1.909, Dr=0.440, Df=0.360
# Epoch 25; Elapsed Time = 105s
# 20/23: G=1.797, Dr=0.447, Df=0.374
# Epoch 26; Elapsed Time = 110s
# 20/23: G=1.940, Dr=0.443, Df=0.401
# Epoch 27; Elapsed Time = 114s
# 20/23: G=2.611, Dr=0.911, Df=0.531
# Epoch 28; Elapsed Time = 119s
# 20/23: G=1.621, Dr=0.424, Df=0.434
# Epoch 29; Elapsed Time = 124s
# 20/23: G=1.629, Dr=0.477, Df=0.414
# Epoch 30; Elapsed Time = 130s
# 20/23: G=1.543, Dr=0.472, Df=0.413
# Epoch 31; Elapsed Time = 135s
# 20/23: G=1.594, Dr=0.421, Df=0.378
# Saving Checkpoint...
# Epoch 32; Elapsed Time = 140s
# 20/23: G=1.714, Dr=0.416, Df=0.348
# Epoch 33; Elapsed Time = 146s
# 20/23: G=1.891, Dr=0.409, Df=0.335
# Epoch 34; Elapsed Time = 151s
# 20/23: G=1.817, Dr=0.420, Df=0.352
# Epoch 35; Elapsed Time = 156s
# 20/23: G=1.949, Dr=0.382, Df=0.324
# Epoch 36; Elapsed Time = 161s
# 20/23: G=2.041, Dr=0.461, Df=0.344
# Epoch 37; Elapsed Time = 166s
# 20/23: G=1.836, Dr=0.427, Df=0.363
# Epoch 38; Elapsed Time = 171s
# 20/23: G=1.726, Dr=0.397, Df=0.357
# Epoch 39; Elapsed Time = 175s
# 20/23: G=1.888, Dr=0.406, Df=0.378
# Epoch 40; Elapsed Time = 180s
# 20/23: G=1.862, Dr=0.372, Df=0.335
# Epoch 41; Elapsed Time = 184s
# 20/23: G=1.797, Dr=0.374, Df=0.346
# Saving Checkpoint...
# Epoch 42; Elapsed Time = 189s
# 20/23: G=1.923, Dr=0.371, Df=0.343
# Epoch 43; Elapsed Time = 193s
# 20/23: G=3.557, Dr=1.852, Df=1.297
# Epoch 44; Elapsed Time = 198s
# 20/23: G=1.229, Dr=0.751, Df=0.842
# Epoch 45; Elapsed Time = 202s
# 20/23: G=1.176, Dr=0.500, Df=0.514
# Epoch 46; Elapsed Time = 206s
# 20/23: G=1.502, Dr=0.469, Df=0.427
# Epoch 47; Elapsed Time = 211s
# 20/23: G=1.608, Dr=0.470, Df=0.474
# Epoch 48; Elapsed Time = 215s
# 20/23: G=1.524, Dr=0.474, Df=0.398
# Epoch 49; Elapsed Time = 220s
# 20/23: G=1.512, Dr=0.412, Df=0.375
# Epoch 50; Elapsed Time = 224s
# 20/23: G=1.585, Dr=0.450, Df=0.407
# Epoch 51; Elapsed Time = 228s
# 20/23: G=1.579, Dr=0.431, Df=0.403
# Saving Checkpoint...
# Epoch 52; Elapsed Time = 233s
# 20/23: G=1.654, Dr=0.394, Df=0.378
# Epoch 53; Elapsed Time = 237s
# 20/23: G=1.822, Dr=0.421, Df=0.373
# Epoch 54; Elapsed Time = 242s
# 20/23: G=1.723, Dr=0.415, Df=0.373
# Epoch 55; Elapsed Time = 246s
# 20/23: G=1.864, Dr=0.409, Df=0.357
# Epoch 56; Elapsed Time = 250s
# 20/23: G=1.811, Dr=0.377, Df=0.323
# Epoch 57; Elapsed Time = 255s
# 20/23: G=1.702, Dr=0.460, Df=0.399
# Epoch 58; Elapsed Time = 259s
# 20/23: G=1.831, Dr=0.371, Df=0.321
# Epoch 59; Elapsed Time = 263s
# 20/23: G=1.976, Dr=0.456, Df=0.347
# Epoch 60; Elapsed Time = 268s
# 20/23: G=1.756, Dr=0.438, Df=0.370
# Epoch 61; Elapsed Time = 272s
# 20/23: G=1.770, Dr=0.379, Df=0.381
# Saving Checkpoint...
# Epoch 62; Elapsed Time = 277s
# 20/23: G=1.885, Dr=0.322, Df=0.343
# Epoch 63; Elapsed Time = 281s
# 20/23: G=1.701, Dr=0.381, Df=0.323
# Epoch 64; Elapsed Time = 285s
# 20/23: G=1.777, Dr=0.425, Df=0.348
# Epoch 65; Elapsed Time = 290s
# 20/23: G=1.935, Dr=0.387, Df=0.319
# Epoch 66; Elapsed Time = 294s
# 20/23: G=1.817, Dr=0.376, Df=0.293
# Epoch 67; Elapsed Time = 298s
# 20/23: G=1.949, Dr=0.366, Df=0.283
# Epoch 68; Elapsed Time = 303s
# 20/23: G=1.892, Dr=0.345, Df=0.294
# Epoch 69; Elapsed Time = 307s
# 20/23: G=1.978, Dr=0.347, Df=0.308
# Epoch 70; Elapsed Time = 311s
# 20/23: G=1.929, Dr=0.357, Df=0.321
# Epoch 71; Elapsed Time = 316s
# 20/23: G=2.075, Dr=0.328, Df=0.285
# Saving Checkpoint...
# Epoch 72; Elapsed Time = 320s
# 20/23: G=2.197, Dr=0.332, Df=0.283
# Epoch 73; Elapsed Time = 325s
# 20/23: G=1.988, Dr=0.343, Df=0.302
# Epoch 74; Elapsed Time = 329s
# 20/23: G=2.192, Dr=0.314, Df=0.270
# Epoch 75; Elapsed Time = 333s
# 20/23: G=2.323, Dr=0.378, Df=0.298
# Epoch 76; Elapsed Time = 338s
# 20/23: G=2.018, Dr=0.344, Df=0.287
# Epoch 77; Elapsed Time = 342s
# 20/23: G=2.133, Dr=0.343, Df=0.277
# Epoch 78; Elapsed Time = 346s
# 20/23: G=2.126, Dr=0.291, Df=0.272
# Epoch 79; Elapsed Time = 351s
# 20/23: G=2.280, Dr=0.276, Df=0.260
# Epoch 80; Elapsed Time = 355s
# 20/23: G=2.130, Dr=0.290, Df=0.262
# Epoch 81; Elapsed Time = 359s
# 20/23: G=2.310, Dr=0.312, Df=0.245
# Saving Checkpoint...
# Epoch 82; Elapsed Time = 364s
# 20/23: G=2.208, Dr=0.327, Df=0.299
# Epoch 83; Elapsed Time = 368s
# 20/23: G=2.719, Dr=0.423, Df=0.325
# Epoch 84; Elapsed Time = 372s
# 20/23: G=2.049, Dr=0.337, Df=0.273
# Epoch 85; Elapsed Time = 377s
# 20/23: G=2.143, Dr=0.297, Df=0.260
# Epoch 86; Elapsed Time = 381s
# 20/23: G=2.102, Dr=0.265, Df=0.229
# Epoch 87; Elapsed Time = 385s
# 20/23: G=2.121, Dr=0.294, Df=0.265
# Epoch 88; Elapsed Time = 390s
# 20/23: G=1.955, Dr=0.387, Df=0.365
# Epoch 89; Elapsed Time = 394s
# 20/23: G=2.143, Dr=0.296, Df=0.251
# Epoch 90; Elapsed Time = 398s
# 20/23: G=2.018, Dr=0.392, Df=0.331
# Epoch 91; Elapsed Time = 403s
# 20/23: G=2.121, Dr=0.308, Df=0.254
# Saving Checkpoint...
# Epoch 92; Elapsed Time = 407s
# 20/23: G=2.245, Dr=0.355, Df=0.285
# Epoch 93; Elapsed Time = 412s
# 20/23: G=2.104, Dr=0.297, Df=0.253
# Epoch 94; Elapsed Time = 416s
# 20/23: G=2.245, Dr=0.283, Df=0.230
# Epoch 95; Elapsed Time = 420s
# 20/23: G=2.302, Dr=0.277, Df=0.226
# Epoch 96; Elapsed Time = 425s
# 20/23: G=2.214, Dr=0.309, Df=0.239
# Epoch 97; Elapsed Time = 429s
# 20/23: G=2.312, Dr=0.272, Df=0.224
# Epoch 98; Elapsed Time = 433s
# 20/23: G=2.372, Dr=0.249, Df=0.202
# Epoch 99; Elapsed Time = 438s
# 20/23: G=2.384, Dr=0.260, Df=0.240
# Epoch 100; Elapsed Time = 442s
# 20/23: G=2.432, Dr=0.272, Df=0.237
# Epoch 101; Elapsed Time = 447s
# 20/23: G=2.711, Dr=0.256, Df=0.273
# Saving Checkpoint...
# Epoch 102; Elapsed Time = 451s
# 20/23: G=2.063, Dr=0.456, Df=0.375
# Epoch 103; Elapsed Time = 455s
# 20/23: G=2.491, Dr=0.206, Df=0.211
# Epoch 104; Elapsed Time = 460s
# 20/23: G=2.477, Dr=0.241, Df=0.218
# Epoch 105; Elapsed Time = 464s
# 20/23: G=2.598, Dr=0.213, Df=0.174
# Epoch 106; Elapsed Time = 469s
# 20/23: G=2.732, Dr=0.240, Df=0.196
# Epoch 107; Elapsed Time = 473s
# 20/23: G=2.571, Dr=0.247, Df=0.243
# Epoch 108; Elapsed Time = 477s
# 20/23: G=2.706, Dr=0.195, Df=0.188
# Epoch 109; Elapsed Time = 482s
# 20/23: G=2.812, Dr=0.217, Df=0.188
# Epoch 110; Elapsed Time = 486s
# 20/23: G=2.762, Dr=0.211, Df=0.208
# Epoch 111; Elapsed Time = 490s
# 20/23: G=2.718, Dr=0.270, Df=0.231
# Saving Checkpoint...
# Epoch 112; Elapsed Time = 495s
# 20/23: G=2.702, Dr=0.185, Df=0.190
# Epoch 113; Elapsed Time = 499s
# 20/23: G=2.787, Dr=0.232, Df=0.182
# Epoch 114; Elapsed Time = 504s
# 20/23: G=2.860, Dr=0.194, Df=0.155
# Epoch 115; Elapsed Time = 508s
# 20/23: G=2.993, Dr=0.226, Df=0.176
# Epoch 116; Elapsed Time = 512s
# 20/23: G=3.046, Dr=0.209, Df=0.207
# Epoch 117; Elapsed Time = 517s
# 20/23: G=2.932, Dr=0.198, Df=0.171
# Epoch 118; Elapsed Time = 521s
# 20/23: G=2.892, Dr=0.163, Df=0.163
# Epoch 119; Elapsed Time = 525s
# 20/23: G=3.086, Dr=0.199, Df=0.153
# Epoch 120; Elapsed Time = 530s
# 20/23: G=2.987, Dr=0.197, Df=0.160
# Epoch 121; Elapsed Time = 534s
# 20/23: G=3.076, Dr=0.154, Df=0.131
# Saving Checkpoint...
# Epoch 122; Elapsed Time = 538s
# 20/23: G=3.021, Dr=0.177, Df=0.156
# Epoch 123; Elapsed Time = 543s
# 20/23: G=3.207, Dr=0.194, Df=0.170
# Epoch 124; Elapsed Time = 547s
# 20/23: G=3.160, Dr=0.159, Df=0.147
# Epoch 125; Elapsed Time = 552s
# 20/23: G=3.285, Dr=0.182, Df=0.172
# Epoch 126; Elapsed Time = 556s
# 20/23: G=3.339, Dr=0.140, Df=0.129
# Epoch 127; Elapsed Time = 560s
# 20/23: G=3.085, Dr=0.222, Df=0.210
# Epoch 128; Elapsed Time = 565s
# 20/23: G=3.136, Dr=0.176, Df=0.135
# Epoch 129; Elapsed Time = 569s
# 20/23: G=3.296, Dr=0.136, Df=0.126
# Epoch 130; Elapsed Time = 573s
# 20/23: G=3.314, Dr=0.166, Df=0.138
# Epoch 131; Elapsed Time = 578s
# 20/23: G=3.238, Dr=0.159, Df=0.132
# Saving Checkpoint...
# Epoch 132; Elapsed Time = 582s
# 20/23: G=3.183, Dr=0.194, Df=0.183
# Epoch 133; Elapsed Time = 586s
# 20/23: G=3.423, Dr=0.185, Df=0.162
# Epoch 134; Elapsed Time = 591s
# 20/23: G=3.191, Dr=0.165, Df=0.152
# Epoch 135; Elapsed Time = 595s
# 20/23: G=3.178, Dr=0.192, Df=0.162
# Epoch 136; Elapsed Time = 599s
# 20/23: G=3.322, Dr=0.134, Df=0.112
# Epoch 137; Elapsed Time = 604s
# 20/23: G=3.440, Dr=0.161, Df=0.154
# Epoch 138; Elapsed Time = 608s
# 20/23: G=3.465, Dr=0.140, Df=0.127
# Epoch 139; Elapsed Time = 612s
# 20/23: G=3.605, Dr=0.153, Df=0.144
# Epoch 140; Elapsed Time = 617s
# 20/23: G=3.376, Dr=0.197, Df=0.161
# Epoch 141; Elapsed Time = 621s
# 20/23: G=3.750, Dr=0.122, Df=0.122
# Saving Checkpoint...
# Epoch 142; Elapsed Time = 626s
# 20/23: G=3.162, Dr=0.261, Df=0.215
# Epoch 143; Elapsed Time = 630s
# 20/23: G=3.323, Dr=0.133, Df=0.123
# Epoch 144; Elapsed Time = 634s
# 20/23: G=3.302, Dr=0.172, Df=0.139
# Epoch 145; Elapsed Time = 639s
# 20/23: G=3.271, Dr=0.172, Df=0.154
# Epoch 146; Elapsed Time = 643s
# 20/23: G=3.476, Dr=0.152, Df=0.143
# Epoch 147; Elapsed Time = 647s
# 20/23: G=3.596, Dr=0.146, Df=0.128
# Epoch 148; Elapsed Time = 652s
# 20/23: G=3.321, Dr=0.151, Df=0.146
# Epoch 149; Elapsed Time = 656s
# 20/23: G=3.605, Dr=0.138, Df=0.133
# Epoch 150; Elapsed Time = 661s
# 20/23: G=3.662, Dr=0.163, Df=0.135
# Epoch 151; Elapsed Time = 665s
# 20/23: G=3.059, Dr=0.302, Df=0.229
# Saving Checkpoint...
# Epoch 152; Elapsed Time = 669s
# 20/23: G=3.357, Dr=0.255, Df=0.215
# Epoch 153; Elapsed Time = 674s
# 20/23: G=2.982, Dr=0.154, Df=0.165
# Epoch 154; Elapsed Time = 678s
# 20/23: G=3.509, Dr=0.124, Df=0.109
# Epoch 155; Elapsed Time = 682s
# 20/23: G=3.400, Dr=0.185, Df=0.155
# Epoch 156; Elapsed Time = 687s
# 20/23: G=3.554, Dr=0.115, Df=0.114
# Epoch 157; Elapsed Time = 691s
# 20/23: G=3.088, Dr=0.250, Df=0.219
# Epoch 158; Elapsed Time = 695s
# 20/23: G=3.405, Dr=0.119, Df=0.116
# Epoch 159; Elapsed Time = 700s
# 20/23: G=3.198, Dr=0.159, Df=0.138
# Epoch 160; Elapsed Time = 704s
# 20/23: G=3.842, Dr=0.125, Df=0.119
# Epoch 161; Elapsed Time = 708s
# 20/23: G=3.313, Dr=0.171, Df=0.139
# Saving Checkpoint...
# Epoch 162; Elapsed Time = 713s
# 20/23: G=3.350, Dr=0.134, Df=0.117
# Epoch 163; Elapsed Time = 717s
# 20/23: G=3.607, Dr=0.136, Df=0.120
# Epoch 164; Elapsed Time = 722s
# 20/23: G=3.448, Dr=0.148, Df=0.115
# Epoch 165; Elapsed Time = 726s
# 20/23: G=3.480, Dr=0.129, Df=0.110
# Epoch 166; Elapsed Time = 730s
# 20/23: G=3.652, Dr=0.144, Df=0.125
# Epoch 167; Elapsed Time = 735s
# 20/23: G=3.949, Dr=0.150, Df=0.131
# Epoch 168; Elapsed Time = 739s
# 20/23: G=3.534, Dr=0.142, Df=0.143
# Epoch 169; Elapsed Time = 743s
# 20/23: G=3.697, Dr=0.130, Df=0.143
# Epoch 170; Elapsed Time = 748s
# 20/23: G=3.701, Dr=0.201, Df=0.170
# Epoch 171; Elapsed Time = 752s
# 20/23: G=3.372, Dr=0.191, Df=0.167
# Saving Checkpoint...
# Epoch 172; Elapsed Time = 757s
# 20/23: G=3.592, Dr=0.147, Df=0.130
# Epoch 173; Elapsed Time = 761s
# 20/23: G=3.755, Dr=0.120, Df=0.106
# Epoch 174; Elapsed Time = 765s
# 20/23: G=3.796, Dr=0.146, Df=0.122
# Epoch 175; Elapsed Time = 770s
# 20/23: G=3.708, Dr=0.155, Df=0.155
# Epoch 176; Elapsed Time = 774s
# 20/23: G=3.809, Dr=0.110, Df=0.118
# Epoch 177; Elapsed Time = 778s
# 20/23: G=3.755, Dr=0.103, Df=0.104
# Epoch 178; Elapsed Time = 782s
# 20/23: G=3.806, Dr=0.149, Df=0.134
# Epoch 179; Elapsed Time = 787s
# 20/23: G=3.425, Dr=0.214, Df=0.157
# Epoch 180; Elapsed Time = 791s
# 20/23: G=3.835, Dr=0.110, Df=0.126
# Epoch 181; Elapsed Time = 795s
# 20/23: G=3.842, Dr=0.114, Df=0.096
# Saving Checkpoint...
# Epoch 182; Elapsed Time = 800s
# 20/23: G=4.082, Dr=0.098, Df=0.089
# Epoch 183; Elapsed Time = 804s
# 20/23: G=3.923, Dr=0.104, Df=0.104
# Epoch 184; Elapsed Time = 809s
# 20/23: G=3.755, Dr=0.105, Df=0.109
# Epoch 185; Elapsed Time = 813s
# 20/23: G=4.227, Dr=0.102, Df=0.111
# Epoch 186; Elapsed Time = 817s
# 20/23: G=3.861, Dr=0.125, Df=0.108
# Epoch 187; Elapsed Time = 822s
# 20/23: G=3.665, Dr=0.221, Df=0.220
# Epoch 188; Elapsed Time = 826s
# 20/23: G=3.933, Dr=0.120, Df=0.105
# Epoch 189; Elapsed Time = 830s
# 20/23: G=4.084, Dr=0.180, Df=0.142
# Epoch 190; Elapsed Time = 835s
# 20/23: G=3.662, Dr=0.119, Df=0.128
# Epoch 191; Elapsed Time = 839s
# 20/23: G=4.012, Dr=0.105, Df=0.128
# Saving Checkpoint...
# Epoch 192; Elapsed Time = 843s
# 20/23: G=4.050, Dr=0.096, Df=0.094
# Epoch 193; Elapsed Time = 848s
# 20/23: G=4.152, Dr=0.096, Df=0.083
# Epoch 194; Elapsed Time = 852s
# 20/23: G=3.855, Dr=0.119, Df=0.109
# Epoch 195; Elapsed Time = 856s
# 20/23: G=4.128, Dr=0.142, Df=0.137
# Epoch 196; Elapsed Time = 861s
# 20/23: G=3.635, Dr=0.271, Df=0.247
# Epoch 197; Elapsed Time = 865s
# 20/23: G=3.599, Dr=0.123, Df=0.120
# Epoch 198; Elapsed Time = 869s
# 20/23: G=4.159, Dr=0.151, Df=0.107
# Epoch 199; Elapsed Time = 874s
# 20/23: G=4.033, Dr=0.074, Df=0.078
# Epoch 200; Elapsed Time = 878s
# 20/23: G=4.096, Dr=0.106, Df=0.090
# Epoch 201; Elapsed Time = 882s
# 20/23: G=3.710, Dr=0.185, Df=0.152
# Saving Checkpoint...
# Epoch 202; Elapsed Time = 887s
# 20/23: G=3.757, Dr=0.108, Df=0.131
# Epoch 203; Elapsed Time = 891s
# 20/23: G=3.866, Dr=0.119, Df=0.096
# Epoch 204; Elapsed Time = 896s
# 20/23: G=4.050, Dr=0.104, Df=0.085
# Epoch 205; Elapsed Time = 900s
# 20/23: G=4.263, Dr=0.103, Df=0.093
# Epoch 206; Elapsed Time = 904s
# 20/23: G=4.224, Dr=0.092, Df=0.084
# Epoch 207; Elapsed Time = 909s
# 20/23: G=4.041, Dr=0.124, Df=0.096
# Epoch 208; Elapsed Time = 913s
# 20/23: G=4.283, Dr=0.086, Df=0.084
# Epoch 209; Elapsed Time = 917s
# 20/23: G=4.861, Dr=0.091, Df=0.239
# Epoch 210; Elapsed Time = 921s
# 20/23: G=4.673, Dr=0.079, Df=0.071
# Epoch 211; Elapsed Time = 926s
# 20/23: G=4.146, Dr=0.128, Df=0.118
# Saving Checkpoint...
# Epoch 212; Elapsed Time = 930s
# 20/23: G=4.559, Dr=0.078, Df=0.066
# Epoch 213; Elapsed Time = 935s
# 20/23: G=4.143, Dr=0.231, Df=0.195
# Epoch 214; Elapsed Time = 939s
# 20/23: G=4.395, Dr=0.082, Df=0.097
# Epoch 215; Elapsed Time = 943s
# 20/23: G=4.080, Dr=0.193, Df=0.135
# Epoch 216; Elapsed Time = 948s
# 20/23: G=4.258, Dr=0.096, Df=0.250
# Epoch 217; Elapsed Time = 952s
# 20/23: G=4.163, Dr=0.137, Df=0.142
# Epoch 218; Elapsed Time = 956s
# 20/23: G=4.098, Dr=0.121, Df=0.250
# Epoch 219; Elapsed Time = 960s
# 20/23: G=4.333, Dr=0.093, Df=0.263
# Epoch 220; Elapsed Time = 965s
# 20/23: G=4.124, Dr=0.217, Df=0.149
# Epoch 221; Elapsed Time = 969s
# 20/23: G=4.053, Dr=0.084, Df=0.081
# Saving Checkpoint...
# Epoch 222; Elapsed Time = 974s
# 20/23: G=4.191, Dr=0.094, Df=0.080
# Epoch 223; Elapsed Time = 978s
# 20/23: G=4.118, Dr=0.130, Df=0.119
# Epoch 224; Elapsed Time = 982s
# 20/23: G=4.114, Dr=0.136, Df=0.110
# Epoch 225; Elapsed Time = 987s
# 20/23: G=4.203, Dr=0.095, Df=0.105
# Epoch 226; Elapsed Time = 991s
# 20/23: G=4.469, Dr=0.135, Df=0.134
# Epoch 227; Elapsed Time = 995s
# 20/23: G=4.157, Dr=0.103, Df=0.083
# Epoch 228; Elapsed Time = 1000s
# 20/23: G=4.348, Dr=0.205, Df=0.147
# Epoch 229; Elapsed Time = 1004s
# 20/23: G=4.407, Dr=0.152, Df=0.104
# Epoch 230; Elapsed Time = 1008s
# 20/23: G=4.080, Dr=0.108, Df=0.112
# Epoch 231; Elapsed Time = 1012s
# 20/23: G=4.239, Dr=0.112, Df=0.119
# Saving Checkpoint...
# Epoch 232; Elapsed Time = 1017s
# 20/23: G=4.168, Dr=0.115, Df=0.112
# Epoch 233; Elapsed Time = 1021s
# 20/23: G=4.270, Dr=0.068, Df=0.067
# Epoch 234; Elapsed Time = 1026s
# 20/23: G=4.536, Dr=0.069, Df=0.057
# Epoch 235; Elapsed Time = 1030s
# 20/23: G=4.349, Dr=0.096, Df=0.079
# Epoch 236; Elapsed Time = 1034s
# 20/23: G=4.441, Dr=0.083, Df=0.071
# Epoch 237; Elapsed Time = 1039s
# 20/23: G=4.432, Dr=0.083, Df=0.075
# Epoch 238; Elapsed Time = 1043s
# 20/23: G=4.563, Dr=0.085, Df=0.071
# Epoch 239; Elapsed Time = 1047s
# 20/23: G=4.637, Dr=0.081, Df=0.073
# Epoch 240; Elapsed Time = 1051s
# 20/23: G=4.115, Dr=0.202, Df=0.197
# Epoch 241; Elapsed Time = 1056s
# 20/23: G=4.565, Dr=0.123, Df=0.092
# Saving Checkpoint...
# Epoch 242; Elapsed Time = 1060s
# 20/23: G=4.825, Dr=0.153, Df=0.125
# Epoch 243; Elapsed Time = 1065s
# 20/23: G=4.318, Dr=0.115, Df=0.120
# Epoch 244; Elapsed Time = 1069s
# 20/23: G=4.359, Dr=0.119, Df=0.085
# Epoch 245; Elapsed Time = 1073s
# 20/23: G=4.336, Dr=0.125, Df=0.106
# Epoch 246; Elapsed Time = 1077s
# 20/23: G=4.143, Dr=0.131, Df=0.095
# Epoch 247; Elapsed Time = 1082s
# 20/23: G=4.278, Dr=0.098, Df=0.101
# Epoch 248; Elapsed Time = 1086s
# 20/23: G=4.475, Dr=0.141, Df=0.104
# Epoch 249; Elapsed Time = 1090s
# 20/23: G=4.039, Dr=0.131, Df=0.105
# Epoch 250; Elapsed Time = 1095s
# 20/23: G=3.923, Dr=0.344, Df=0.253
# Epoch 251; Elapsed Time = 1099s
# 20/23: G=4.269, Dr=0.154, Df=0.135
# Saving Checkpoint...
# Epoch 252; Elapsed Time = 1103s
# 20/23: G=4.203, Dr=0.091, Df=0.094
# Epoch 253; Elapsed Time = 1108s
# 20/23: G=4.332, Dr=0.082, Df=0.101
# Epoch 254; Elapsed Time = 1112s
# 20/23: G=4.065, Dr=0.146, Df=0.107
# Epoch 255; Elapsed Time = 1116s
# 20/23: G=4.446, Dr=0.064, Df=0.076
# Epoch 256; Elapsed Time = 1121s
# 20/23: G=4.735, Dr=0.072, Df=0.215
# Epoch 257; Elapsed Time = 1125s
# 20/23: G=4.578, Dr=0.146, Df=0.144
# Epoch 258; Elapsed Time = 1129s
# 20/23: G=4.343, Dr=0.095, Df=0.078
# Epoch 259; Elapsed Time = 1134s
# 20/23: G=4.702, Dr=0.083, Df=0.067
# Epoch 260; Elapsed Time = 1138s
# 20/23: G=4.454, Dr=0.083, Df=0.073
# Epoch 261; Elapsed Time = 1142s
# 20/23: G=4.630, Dr=0.093, Df=0.082
# Saving Checkpoint...
# Epoch 262; Elapsed Time = 1147s
# 20/23: G=4.300, Dr=0.116, Df=0.087
# Epoch 263; Elapsed Time = 1151s
# 20/23: G=4.022, Dr=0.141, Df=0.103
# Epoch 264; Elapsed Time = 1155s
# 20/23: G=4.324, Dr=0.068, Df=0.061
# Epoch 265; Elapsed Time = 1160s
# 20/23: G=4.245, Dr=0.123, Df=0.097
# Epoch 266; Elapsed Time = 1164s
# 20/23: G=4.990, Dr=0.112, Df=0.082
# Epoch 267; Elapsed Time = 1168s
# 20/23: G=3.253, Dr=0.255, Df=0.331
# Epoch 268; Elapsed Time = 1173s
# 20/23: G=4.406, Dr=0.084, Df=0.075
# Epoch 269; Elapsed Time = 1177s
# 20/23: G=4.363, Dr=0.092, Df=0.097
# Epoch 270; Elapsed Time = 1181s
# 20/23: G=4.207, Dr=0.097, Df=0.094
# Epoch 271; Elapsed Time = 1185s
# 20/23: G=4.387, Dr=0.082, Df=0.067
# Saving Checkpoint...
# Epoch 272; Elapsed Time = 1189s
# 20/23: G=4.868, Dr=0.122, Df=0.092
# Epoch 273; Elapsed Time = 1193s
# 20/23: G=4.374, Dr=0.061, Df=0.060
# Epoch 274; Elapsed Time = 1197s
# 20/23: G=4.518, Dr=0.062, Df=0.067
# Epoch 275; Elapsed Time = 1201s
# 20/23: G=5.039, Dr=0.085, Df=0.075
# Epoch 276; Elapsed Time = 1205s
# 20/23: G=4.789, Dr=0.121, Df=0.084
# Epoch 277; Elapsed Time = 1209s
# 20/23: G=4.875, Dr=0.085, Df=0.065
# Epoch 278; Elapsed Time = 1213s
# 20/23: G=5.052, Dr=0.053, Df=0.083
# Epoch 279; Elapsed Time = 1217s
# 20/23: G=4.647, Dr=0.206, Df=0.199
# Epoch 280; Elapsed Time = 1221s
# 20/23: G=4.596, Dr=0.088, Df=0.093
# Epoch 281; Elapsed Time = 1224s
# 20/23: G=4.653, Dr=0.064, Df=0.066
# Saving Checkpoint...
# Epoch 282; Elapsed Time = 1229s
# 20/23: G=4.984, Dr=0.074, Df=0.059
# Epoch 283; Elapsed Time = 1233s
# 20/23: G=5.160, Dr=0.142, Df=0.110
# Epoch 284; Elapsed Time = 1237s
# 20/23: G=5.781, Dr=0.093, Df=0.068
# Epoch 285; Elapsed Time = 1241s
# 20/23: G=4.654, Dr=0.393, Df=0.291
# Epoch 286; Elapsed Time = 1245s
# 20/23: G=4.391, Dr=0.087, Df=0.091
# Epoch 287; Elapsed Time = 1248s
# 20/23: G=4.940, Dr=0.081, Df=0.068
# Epoch 288; Elapsed Time = 1252s
# 20/23: G=4.914, Dr=0.062, Df=0.048
# Epoch 289; Elapsed Time = 1256s
# 20/23: G=3.963, Dr=0.282, Df=0.256
# Epoch 290; Elapsed Time = 1260s
# 20/23: G=4.135, Dr=0.332, Df=0.290
# Epoch 291; Elapsed Time = 1264s
# 20/23: G=3.857, Dr=0.163, Df=0.305
# Saving Checkpoint...
# Epoch 292; Elapsed Time = 1269s
# 20/23: G=4.184, Dr=0.061, Df=0.054
# Epoch 293; Elapsed Time = 1272s
# 20/23: G=4.713, Dr=0.059, Df=0.041
# Epoch 294; Elapsed Time = 1276s
# 20/23: G=5.153, Dr=0.084, Df=0.092
# Epoch 295; Elapsed Time = 1280s
# 20/23: G=4.463, Dr=0.146, Df=0.131
# Epoch 296; Elapsed Time = 1284s
# 20/23: G=4.398, Dr=0.138, Df=0.135
# Epoch 297; Elapsed Time = 1288s
# 20/23: G=4.745, Dr=0.075, Df=0.071
# Epoch 298; Elapsed Time = 1292s
# 20/23: G=4.854, Dr=0.077, Df=0.064
# Epoch 299; Elapsed Time = 1296s
# 20/23: G=5.054, Dr=0.094, Df=0.074
# Epoch 300; Elapsed Time = 1300s
# 20/23: G=5.149, Dr=0.080, Df=0.068
# Epoch 301; Elapsed Time = 1304s
# 20/23: G=4.601, Dr=0.122, Df=0.098
# Saving Checkpoint...
# Epoch 302; Elapsed Time = 1308s
# 20/23: G=4.992, Dr=0.084, Df=0.077
# Epoch 303; Elapsed Time = 1312s
# 20/23: G=5.004, Dr=0.107, Df=0.093
# Epoch 304; Elapsed Time = 1316s
# 20/23: G=4.743, Dr=0.168, Df=0.135
# Epoch 305; Elapsed Time = 1320s
# 20/23: G=5.241, Dr=0.088, Df=0.081
# Epoch 306; Elapsed Time = 1324s
# 20/23: G=4.997, Dr=0.099, Df=0.080
# Epoch 307; Elapsed Time = 1328s
# 20/23: G=4.553, Dr=0.089, Df=0.078
# Epoch 308; Elapsed Time = 1332s
# 20/23: G=4.990, Dr=0.062, Df=0.084
# Epoch 309; Elapsed Time = 1336s
# 20/23: G=5.055, Dr=0.082, Df=0.082
# Epoch 310; Elapsed Time = 1340s
# 20/23: G=4.924, Dr=0.131, Df=0.114
# Epoch 311; Elapsed Time = 1344s
# 20/23: G=5.256, Dr=0.068, Df=0.057
# Saving Checkpoint...
# Epoch 312; Elapsed Time = 1348s
# 20/23: G=5.021, Dr=0.059, Df=0.053
# Epoch 313; Elapsed Time = 1352s
# 20/23: G=5.206, Dr=0.087, Df=0.083
# Epoch 314; Elapsed Time = 1356s
# 20/23: G=5.068, Dr=0.164, Df=0.110
# Epoch 315; Elapsed Time = 1360s
# 20/23: G=5.059, Dr=0.060, Df=0.050
# Epoch 316; Elapsed Time = 1364s
# 20/23: G=5.304, Dr=0.040, Df=0.039
# Epoch 317; Elapsed Time = 1368s
# 20/23: G=5.101, Dr=0.378, Df=0.199
# Epoch 318; Elapsed Time = 1372s
# 20/23: G=3.241, Dr=0.251, Df=0.409
# Epoch 319; Elapsed Time = 1376s
# 20/23: G=4.314, Dr=0.119, Df=0.086
# Epoch 320; Elapsed Time = 1380s
# 20/23: G=4.395, Dr=0.077, Df=0.077
# Epoch 321; Elapsed Time = 1384s
# 20/23: G=4.855, Dr=0.089, Df=0.098
# Saving Checkpoint...
# Epoch 322; Elapsed Time = 1388s
# 20/23: G=5.001, Dr=3.419, Df=7.5909
# Epoch 323; Elapsed Time = 1392s
# 20/23: G=1.704, Dr=0.482, Df=0.540
# Epoch 324; Elapsed Time = 1396s
# 20/23: G=2.028, Dr=0.267, Df=0.278
# Epoch 325; Elapsed Time = 1400s
# 20/23: G=2.630, Dr=0.177, Df=0.202
# Epoch 326; Elapsed Time = 1404s
# 20/23: G=3.607, Dr=0.130, Df=0.133
# Epoch 327; Elapsed Time = 1408s
# 20/23: G=3.537, Dr=0.091, Df=0.142
# Epoch 328; Elapsed Time = 1412s
# 20/23: G=3.627, Dr=0.100, Df=0.126
# Epoch 329; Elapsed Time = 1416s
# 20/23: G=3.936, Dr=0.086, Df=0.089
# Epoch 330; Elapsed Time = 1420s
# 20/23: G=3.998, Dr=0.095, Df=0.105
# Epoch 331; Elapsed Time = 1424s
# 20/23: G=4.234, Dr=0.117, Df=0.135
# Saving Checkpoint...
# Epoch 332; Elapsed Time = 1428s
# 20/23: G=4.260, Dr=0.150, Df=0.282
# Epoch 333; Elapsed Time = 1432s
# 20/23: G=4.429, Dr=0.115, Df=0.088
# Epoch 334; Elapsed Time = 1436s
# 20/23: G=4.464, Dr=0.132, Df=0.096
# Epoch 335; Elapsed Time = 1440s
# 20/23: G=4.410, Dr=0.104, Df=0.115
# Epoch 336; Elapsed Time = 1444s
# 20/23: G=4.704, Dr=0.090, Df=0.091
# Epoch 337; Elapsed Time = 1448s
# 20/23: G=4.846, Dr=0.069, Df=0.070
# Epoch 338; Elapsed Time = 1452s
# 20/23: G=4.721, Dr=0.088, Df=0.097
# Epoch 339; Elapsed Time = 1456s
# 20/23: G=4.853, Dr=0.098, Df=0.073
# Epoch 340; Elapsed Time = 1460s
# 20/23: G=5.025, Dr=0.170, Df=0.145
# Epoch 341; Elapsed Time = 1464s
# 20/23: G=4.703, Dr=0.129, Df=0.101
# Saving Checkpoint...
# Epoch 342; Elapsed Time = 1468s
# 20/23: G=4.572, Dr=0.128, Df=0.104
# Epoch 343; Elapsed Time = 1472s
# 20/23: G=4.591, Dr=0.117, Df=0.099
# Epoch 344; Elapsed Time = 1477s
# 20/23: G=4.634, Dr=0.082, Df=0.096
# Epoch 345; Elapsed Time = 1481s
# 20/23: G=5.118, Dr=0.099, Df=0.077
# Epoch 346; Elapsed Time = 1485s
# 20/23: G=3.894, Dr=0.621, Df=2.740
# Epoch 347; Elapsed Time = 1490s
# 20/23: G=4.384, Dr=0.071, Df=0.085
# Epoch 348; Elapsed Time = 1494s
# 20/23: G=4.732, Dr=0.120, Df=0.100
# Epoch 349; Elapsed Time = 1498s
# 20/23: G=4.274, Dr=0.109, Df=0.111
# Epoch 350; Elapsed Time = 1503s
# 20/23: G=4.667, Dr=0.078, Df=0.059
# Epoch 351; Elapsed Time = 1507s
# 20/23: G=4.798, Dr=0.091, Df=0.097
# Saving Checkpoint...
# Epoch 352; Elapsed Time = 1512s
# 20/23: G=4.697, Dr=0.106, Df=0.097
# Epoch 353; Elapsed Time = 1516s
# 20/23: G=4.612, Dr=0.081, Df=0.064
# Epoch 354; Elapsed Time = 1520s
# 20/23: G=4.718, Dr=0.116, Df=0.106
# Epoch 355; Elapsed Time = 1524s
# 20/23: G=4.628, Dr=0.077, Df=0.080
# Epoch 356; Elapsed Time = 1529s
# 20/23: G=4.676, Dr=0.221, Df=0.127
# Epoch 357; Elapsed Time = 1533s
# 20/23: G=4.804, Dr=0.091, Df=0.099
# Epoch 358; Elapsed Time = 1537s
# 20/23: G=4.769, Dr=0.093, Df=0.081
# Epoch 359; Elapsed Time = 1542s
# 20/23: G=4.790, Dr=0.078, Df=0.237
# Epoch 360; Elapsed Time = 1546s
# 20/23: G=4.890, Dr=0.057, Df=0.056
# Epoch 361; Elapsed Time = 1550s
# 20/23: G=5.146, Dr=0.081, Df=0.079
# Saving Checkpoint...
# Epoch 362; Elapsed Time = 1555s
# 20/23: G=5.257, Dr=0.096, Df=0.070
# Epoch 363; Elapsed Time = 1559s
# 20/23: G=4.825, Dr=0.199, Df=0.219
# Epoch 364; Elapsed Time = 1563s
# 20/23: G=4.466, Dr=0.251, Df=0.377
# Epoch 365; Elapsed Time = 1568s
# 20/23: G=4.456, Dr=0.073, Df=0.087
# Epoch 366; Elapsed Time = 1572s
# 20/23: G=4.560, Dr=0.107, Df=0.090
# Epoch 367; Elapsed Time = 1576s
# 20/23: G=4.963, Dr=0.054, Df=0.221
# Epoch 368; Elapsed Time = 1581s
# 20/23: G=4.814, Dr=0.072, Df=0.063
# Epoch 369; Elapsed Time = 1585s
# 20/23: G=4.877, Dr=0.082, Df=0.079
# Epoch 370; Elapsed Time = 1589s
# 20/23: G=4.883, Dr=0.090, Df=0.080
# Epoch 371; Elapsed Time = 1594s
# 20/23: G=5.234, Dr=0.074, Df=0.075
# Saving Checkpoint...
# Epoch 372; Elapsed Time = 1598s
# 20/23: G=5.188, Dr=0.097, Df=0.257
# Epoch 373; Elapsed Time = 1603s
# 20/23: G=5.159, Dr=0.137, Df=0.089
# Epoch 374; Elapsed Time = 1607s
# 20/23: G=4.780, Dr=0.079, Df=0.060
# Epoch 375; Elapsed Time = 1611s
# 20/23: G=4.988, Dr=0.091, Df=0.082
# Epoch 376; Elapsed Time = 1616s
# 20/23: G=5.142, Dr=0.106, Df=0.077
# Epoch 377; Elapsed Time = 1620s
# 20/23: G=5.255, Dr=0.081, Df=0.075
# Epoch 378; Elapsed Time = 1624s
# 20/23: G=5.183, Dr=0.085, Df=0.249
# Epoch 379; Elapsed Time = 1628s
# 20/23: G=5.329, Dr=0.072, Df=0.069
# Epoch 380; Elapsed Time = 1633s
# 20/23: G=5.504, Dr=0.093, Df=0.103
# Epoch 381; Elapsed Time = 1637s
# 20/23: G=4.939, Dr=0.124, Df=0.064
# Saving Checkpoint...
# Epoch 382; Elapsed Time = 1642s
# 20/23: G=5.147, Dr=0.106, Df=0.092
# Epoch 383; Elapsed Time = 1646s
# 20/23: G=4.786, Dr=0.075, Df=0.092
# Epoch 384; Elapsed Time = 1650s
# 20/23: G=5.465, Dr=0.054, Df=0.043
# Epoch 385; Elapsed Time = 1655s
# 20/23: G=4.993, Dr=0.094, Df=0.097
# Epoch 386; Elapsed Time = 1659s
# 20/23: G=5.062, Dr=0.070, Df=0.060
# Epoch 387; Elapsed Time = 1663s
# 20/23: G=5.489, Dr=0.087, Df=0.075
# Epoch 388; Elapsed Time = 1668s
# 20/23: G=5.132, Dr=0.110, Df=0.097
# Epoch 389; Elapsed Time = 1672s
# 20/23: G=4.897, Dr=0.052, Df=0.051
# Epoch 390; Elapsed Time = 1676s
# 20/23: G=5.315, Dr=0.060, Df=0.053
# Epoch 391; Elapsed Time = 1681s
# 20/23: G=5.194, Dr=0.069, Df=0.050
# Saving Checkpoint...
# Epoch 392; Elapsed Time = 1685s
# 20/23: G=5.316, Dr=0.052, Df=0.042
# Epoch 393; Elapsed Time = 1689s
# 20/23: G=4.787, Dr=0.089, Df=0.091
# Epoch 394; Elapsed Time = 1694s
# 20/23: G=5.291, Dr=0.069, Df=0.065
# Epoch 395; Elapsed Time = 1698s
# 20/23: G=5.506, Dr=0.046, Df=0.057
# Epoch 396; Elapsed Time = 1702s
# 20/23: G=5.268, Dr=0.079, Df=0.063
# Epoch 397; Elapsed Time = 1707s
# 20/23: G=5.330, Dr=0.069, Df=0.079
# Epoch 398; Elapsed Time = 1711s
# 20/23: G=5.657, Dr=0.099, Df=0.102
# Epoch 399; Elapsed Time = 1715s
# 20/23: G=5.307, Dr=0.060, Df=0.039
# Epoch 400; Elapsed Time = 1720s
# 20/23: G=5.517, Dr=0.044, Df=0.034
# Epoch 401; Elapsed Time = 1724s
# 20/23: G=5.722, Dr=0.060, Df=0.051
# Saving Checkpoint...
# Epoch 402; Elapsed Time = 1729s
# 20/23: G=5.910, Dr=0.114, Df=0.105
# Epoch 403; Elapsed Time = 1733s
# 20/23: G=5.468, Dr=0.056, Df=0.069
# Epoch 404; Elapsed Time = 1737s
# 20/23: G=5.831, Dr=0.091, Df=0.090
# Epoch 405; Elapsed Time = 1741s
# 20/23: G=4.749, Dr=0.156, Df=0.152
# Epoch 406; Elapsed Time = 1746s
# 20/23: G=4.786, Dr=0.082, Df=0.072
# Epoch 407; Elapsed Time = 1750s
# 20/23: G=4.966, Dr=0.076, Df=0.068
# Epoch 408; Elapsed Time = 1754s
# 20/23: G=5.154, Dr=0.121, Df=0.058
# Epoch 409; Elapsed Time = 1759s
# 20/23: G=5.198, Dr=0.056, Df=0.065
# Epoch 410; Elapsed Time = 1763s
# 20/23: G=4.726, Dr=0.073, Df=0.068
# Epoch 411; Elapsed Time = 1767s
# 20/23: G=4.799, Dr=0.284, Df=2.536
# Saving Checkpoint...
# Epoch 412; Elapsed Time = 1772s
# 20/23: G=5.278, Dr=0.069, Df=0.066
# Epoch 413; Elapsed Time = 1776s
# 20/23: G=5.027, Dr=0.032, Df=0.034
# Epoch 414; Elapsed Time = 1781s
# 20/23: G=5.342, Dr=0.071, Df=0.048
# Epoch 415; Elapsed Time = 1785s
# 20/23: G=5.475, Dr=0.071, Df=0.058
# Epoch 416; Elapsed Time = 1789s
# 20/23: G=5.117, Dr=0.064, Df=0.077
# Epoch 417; Elapsed Time = 1794s
# 20/23: G=5.733, Dr=0.040, Df=0.042
# Epoch 418; Elapsed Time = 1798s
# 20/23: G=5.442, Dr=0.069, Df=0.071
# Epoch 419; Elapsed Time = 1802s
# 20/23: G=5.346, Dr=0.161, Df=0.142
# Epoch 420; Elapsed Time = 1807s
# 20/23: G=4.779, Dr=0.081, Df=0.090
# Epoch 421; Elapsed Time = 1811s
# 20/23: G=5.384, Dr=0.136, Df=0.140
# Saving Checkpoint...
# Epoch 422; Elapsed Time = 1816s
# 20/23: G=5.266, Dr=0.058, Df=0.046
# Epoch 423; Elapsed Time = 1820s
# 20/23: G=5.188, Dr=0.068, Df=0.056
# Epoch 424; Elapsed Time = 1824s
# 20/23: G=5.367, Dr=0.041, Df=0.031
# Epoch 425; Elapsed Time = 1829s
# 20/23: G=5.454, Dr=0.041, Df=0.042
# Epoch 426; Elapsed Time = 1833s
# 20/23: G=5.909, Dr=0.064, Df=0.072
# Epoch 427; Elapsed Time = 1837s
# 20/23: G=5.359, Dr=0.114, Df=0.236
# Epoch 428; Elapsed Time = 1842s
# 20/23: G=5.513, Dr=0.038, Df=0.051
# Epoch 429; Elapsed Time = 1846s
# 20/23: G=5.508, Dr=0.045, Df=0.044
# Epoch 430; Elapsed Time = 1850s
# 20/23: G=5.367, Dr=0.080, Df=0.082
# Epoch 431; Elapsed Time = 1855s
# 20/23: G=5.494, Dr=0.058, Df=0.054
# Saving Checkpoint...
# Epoch 432; Elapsed Time = 1859s
# 20/23: G=5.101, Dr=0.116, Df=0.082
# Epoch 433; Elapsed Time = 1863s
# 20/23: G=5.704, Dr=0.100, Df=0.068
# Epoch 434; Elapsed Time = 1868s
# 20/23: G=4.925, Dr=0.079, Df=0.045
# Epoch 435; Elapsed Time = 1872s
# 20/23: G=5.311, Dr=0.068, Df=0.044
# Epoch 436; Elapsed Time = 1876s
# 20/23: G=5.459, Dr=0.031, Df=0.030
# Epoch 437; Elapsed Time = 1881s
# 20/23: G=5.843, Dr=0.042, Df=0.064
# Epoch 438; Elapsed Time = 1885s
# 20/23: G=5.487, Dr=0.120, Df=0.245
# Epoch 439; Elapsed Time = 1889s
# 20/23: G=5.309, Dr=0.113, Df=0.255
# Epoch 440; Elapsed Time = 1894s
# 20/23: G=5.210, Dr=0.057, Df=0.065
# Epoch 441; Elapsed Time = 1898s
# 20/23: G=5.567, Dr=0.059, Df=0.057
# Saving Checkpoint...
# Epoch 442; Elapsed Time = 1903s
# 20/23: G=5.333, Dr=0.053, Df=0.046
# Epoch 443; Elapsed Time = 1907s
# 20/23: G=5.552, Dr=0.063, Df=0.068
# Epoch 444; Elapsed Time = 1911s
# 20/23: G=5.475, Dr=0.077, Df=0.242
# Epoch 445; Elapsed Time = 1916s
# 20/23: G=5.419, Dr=0.049, Df=0.037
# Epoch 446; Elapsed Time = 1920s
# 20/23: G=5.472, Dr=0.052, Df=0.035
# Epoch 447; Elapsed Time = 1924s
# 20/23: G=6.363, Dr=0.083, Df=0.061
# Epoch 448; Elapsed Time = 1929s
# 20/23: G=5.606, Dr=0.101, Df=0.243
# Epoch 449; Elapsed Time = 1933s
# 20/23: G=5.361, Dr=0.065, Df=0.073
# Epoch 450; Elapsed Time = 1937s
# 20/23: G=5.756, Dr=0.117, Df=0.099
# Epoch 451; Elapsed Time = 1942s
# 20/23: G=5.505, Dr=0.111, Df=0.107
# Saving Checkpoint...
# Epoch 452; Elapsed Time = 1946s
# 20/23: G=5.416, Dr=0.061, Df=0.047
# Epoch 453; Elapsed Time = 1950s
# 20/23: G=5.434, Dr=0.055, Df=0.059
# Epoch 454; Elapsed Time = 1955s
# 20/23: G=5.789, Dr=0.073, Df=0.061
# Epoch 455; Elapsed Time = 1959s
# 20/23: G=5.401, Dr=0.045, Df=0.039
# Epoch 456; Elapsed Time = 1963s
# 20/23: G=5.654, Dr=0.023, Df=0.040
# Epoch 457; Elapsed Time = 1968s
# 20/23: G=5.682, Dr=0.064, Df=0.052
# Epoch 458; Elapsed Time = 1972s
# 20/23: G=5.949, Dr=0.144, Df=0.118
# Epoch 459; Elapsed Time = 1976s
# 20/23: G=5.265, Dr=0.080, Df=0.073
# Epoch 460; Elapsed Time = 1981s
# 20/23: G=5.429, Dr=0.095, Df=0.060
# Epoch 461; Elapsed Time = 1985s
# 20/23: G=5.861, Dr=0.059, Df=0.067
# Saving Checkpoint...
# Epoch 462; Elapsed Time = 1990s
# 20/23: G=5.637, Dr=0.091, Df=0.083
# Epoch 463; Elapsed Time = 1994s
# 20/23: G=6.087, Dr=0.359, Df=1.909
# Epoch 464; Elapsed Time = 1998s
# 20/23: G=5.468, Dr=0.100, Df=0.097
# Epoch 465; Elapsed Time = 2003s
# 20/23: G=4.963, Dr=0.054, Df=0.040
# Epoch 466; Elapsed Time = 2007s
# 20/23: G=5.911, Dr=0.072, Df=0.049
# Epoch 467; Elapsed Time = 2011s
# 20/23: G=5.793, Dr=0.033, Df=0.035
# Epoch 468; Elapsed Time = 2016s
# 20/23: G=5.796, Dr=0.037, Df=0.033
# Epoch 469; Elapsed Time = 2020s
# 20/23: G=5.982, Dr=0.053, Df=0.046
# Epoch 470; Elapsed Time = 2024s
# 20/23: G=5.309, Dr=0.109, Df=0.078
# Epoch 471; Elapsed Time = 2029s
# 20/23: G=5.379, Dr=0.086, Df=0.245
# Saving Checkpoint...
# Epoch 472; Elapsed Time = 2033s
# 20/23: G=5.227, Dr=0.053, Df=0.050
# Epoch 473; Elapsed Time = 2037s
# 20/23: G=5.548, Dr=0.060, Df=0.037
# Epoch 474; Elapsed Time = 2042s
# 20/23: G=5.920, Dr=0.088, Df=0.056
# Epoch 475; Elapsed Time = 2046s
# 20/23: G=5.362, Dr=0.066, Df=0.066
# Epoch 476; Elapsed Time = 2050s
# 20/23: G=5.340, Dr=0.046, Df=0.038
# Epoch 477; Elapsed Time = 2055s
# 20/23: G=5.360, Dr=0.056, Df=0.031
# Epoch 478; Elapsed Time = 2059s
# 20/23: G=5.846, Dr=0.292, Df=0.296
# Epoch 479; Elapsed Time = 2063s
# 20/23: G=5.088, Dr=0.061, Df=0.078
# Epoch 480; Elapsed Time = 2068s
# 20/23: G=5.909, Dr=0.050, Df=0.196
# Epoch 481; Elapsed Time = 2072s
# 20/23: G=5.461, Dr=0.041, Df=0.057
# Saving Checkpoint...
# Epoch 482; Elapsed Time = 2077s
# 20/23: G=5.859, Dr=0.068, Df=0.052
# Epoch 483; Elapsed Time = 2081s
# 20/23: G=5.947, Dr=0.146, Df=1.029
# Epoch 484; Elapsed Time = 2085s
# 20/23: G=5.495, Dr=0.100, Df=0.105
# Epoch 485; Elapsed Time = 2090s
# 20/23: G=5.282, Dr=0.048, Df=0.052
# Epoch 486; Elapsed Time = 2094s
# 20/23: G=5.368, Dr=0.065, Df=0.058
# Epoch 487; Elapsed Time = 2098s
# 20/23: G=5.507, Dr=0.047, Df=0.046
# Epoch 488; Elapsed Time = 2103s
# 20/23: G=6.118, Dr=0.031, Df=0.035
# Epoch 489; Elapsed Time = 2107s
# 20/23: G=5.942, Dr=0.053, Df=0.039
# Epoch 490; Elapsed Time = 2111s
# 20/23: G=5.659, Dr=0.062, Df=0.049
# Epoch 491; Elapsed Time = 2115s
# 20/23: G=5.757, Dr=0.130, Df=0.131
# Saving Checkpoint...
# Epoch 492; Elapsed Time = 2120s
# 20/23: G=5.607, Dr=0.045, Df=0.049
# Epoch 493; Elapsed Time = 2124s
# 20/23: G=6.011, Dr=0.044, Df=0.032
# Epoch 494; Elapsed Time = 2129s
# 20/23: G=5.902, Dr=0.044, Df=0.051
# Epoch 495; Elapsed Time = 2133s
# 20/23: G=5.773, Dr=0.028, Df=0.033
# Epoch 496; Elapsed Time = 2137s
# 20/23: G=5.808, Dr=0.049, Df=0.049
# Epoch 497; Elapsed Time = 2142s
# 20/23: G=6.202, Dr=0.054, Df=0.055
# Epoch 498; Elapsed Time = 2146s
# 20/23: G=6.629, Dr=0.107, Df=0.104
# Epoch 499; Elapsed Time = 2150s
# 20/23: G=6.355, Dr=0.117, Df=0.212
# Epoch 500; Elapsed Time = 2155s
# 20/23: G=5.874, Dr=0.087, Df=0.067

# %%
lt, lv = runGAN(chkpt_name='PorcelainYourRun', dataset='data/RealImageData/', epochs=500, use_attn=True, bw=False, size=160)

# %%
# Plots the loss values for the generator, and the discrimininator on real and fake images.
lt_df = pd.melt(pd.DataFrame(lt).rename({0:'G',1:'D_R', 2:'D_F'}, axis=1), ignore_index=False).reset_index()
sns.lineplot(data=lt_df, x='index', y='value', hue='variable')
# Out:
# <AxesSubplot:xlabel='index', ylabel='value'>

# %% [markdown]
# ![alt text](data/PresentationImages/LongTrainingLoss.png "LTL")

# %% [markdown]
# ![alt text](data/PresentationImages/Ash_and_Gary.png "Rivals")

# %% [markdown]
# ### The generator and discriminator are battling each other, and in the process making each other better! However, this makes the loss values a bit confusing, as they don't seem to converge as a normal network would. They seem to hover in equilibrium or go in the wrong direction sometimes, even though the quality of images is improving.

# %% [markdown]
# ### This is common for GANs, and why our evaluation criteria of data quality is often subjective. There is much debate over the best way to measure objectively and precisely the quality / realness of the output. Since it is so hard to define what is 'realistic' data, that is why GANs are actually important because you don't have to explicitly define what is 'realness.'

# %%
# Generate some new images!
lt, lv = runGAN(chkpt_name='PorcelainDemo', dataset='data/RealImageData/', use_attn=True, gen_or_train='gen', gen_name_mod='porcelain_', folder_mod='Porcelain/')

# %% [markdown]
# ### These are cool! Unfortunately this network and dataset are kind of small - here is what you could make using a larger version of this same network / dataset:
#
# ![alt text](data/PresentationImages/109.png "Plate 1")
# ![alt text](data/PresentationImages/119.png "Plate 2")
#
# ### Using different architectures and better datasets can give you even higher quality images!
#
# ![alt text](data/PresentationImages/styleGan.jpg "StyleGAN")

# %% [markdown]
# ![alt text](data/PresentationImages/gan_output.jpeg "Plate 2")

# %% [markdown]
# ## Well that was fun! But I was promised profit also! Where is my profit?

# %% [markdown]
# ## Solution: Sell your plate images as NFTs on the internet! Instant profit!

# %% [markdown]
# ![alt text](data/PresentationImages/YourNFT.png "NFT")

# %% [markdown]
# ## Ok, now I have a ton of cryptocurrency! What now?

# %% [markdown]
# ## Solution: Become a degenerate cryptocurrency day trader who uses machine learning!

# %% [markdown]
# ![alt text](data/PresentationImages/stonks.jpg "stonks")

# %% [markdown]
# ## BTC Price data:

# %%
btc = pd.read_parquet('data/FinancialData/BTC-USD.pq')
btc
# Out:
#                     datetime       close
# 0        2013-04-01 00:07:00     93.3000
# 1        2013-04-01 00:08:00    100.0000
# 2        2013-04-01 00:09:00     93.3000
# 3        2013-04-01 00:11:00     93.4700
# 4        2013-04-01 00:12:00     93.4700
# ...                      ...         ...
# 3147684  2021-01-01 15:05:00  29352.0000
# 3147685  2021-01-01 15:06:00  29363.6385
# 3147686  2021-01-01 15:07:00  29357.0000
# 3147687  2021-01-01 15:08:00  29367.0000
# 3147688  2021-01-01 15:09:00  29367.0000
#
# [3147689 rows x 2 columns]

# %%
# Here we are turning the financial time series into an image. In the real world this is 
# unnecessary / frowned upon. Use your data in its natural format, and an architecture that
# is suitable. But for this demo, it allows us to use roughly the same architecture from before.

def seriesToImage(image, finalValue, counter, size):
    image = (image - image.min()) / (image.max() - image.min()) #to normalize
    image = image * 256
    
    #image = np.expand_dims(image, 2)
    image = Image.fromarray(np.uint8(image) , 'L')
    #sv = np.zeros([size, size, 2])
    #sv[:, :, 0] = 1000 
    #sv[:, :, 1] = 200 

    #hsv_image = np.concatenate([image, sv], 2).astype(np.uint8)
    #rgb_image = cv2.cvtColor(hsv_image, cv2.COLOR_HSV2RGB)
    #im = Image.fromarray(rgb_image)
    
    # Seperate images where the final value of the series is lower than 
    # the first from those where it is higher. i.e. a loss or a gain
    
    if finalValue < 0:
        image.save('data/FinancialImages/BW/Neg/' + str(counter) + '_' + "{:.5f}".format(finalValue)+ '.png', "PNG")
    if finalValue >= 0:
        image.save('data/FinancialImages/BW/Pos/' + str(counter) + '_' + "{:.5f}".format(finalValue)+ '.png', "PNG")

# %%
size = 32

for j in range(3073):
    if j % 500 == 0:
        print(j)
    counter = 0
    imageMatrix = np.zeros((size, size))
    startVal = j * (size*size)
    for i in range(startVal, startVal + (size*size), size):
        temp = btc[i:i+size]['close'].reset_index(drop=True)
        
        if counter == 0:
            
            start = temp[0]

        imageMatrix[counter, :] = ((start/temp)-1).to_numpy()
        counter +=1
        
    seriesToImage(imageMatrix, imageMatrix[size-1,size-1], j, size)
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# 2500
# 3000

# %% [markdown]
# ### Positive Series (White == Higher)
# ![alt text](data/PresentationImages/FinPosBW.png "Pos")
# ### Negative Series (Black == Lower)
# ![alt text](data/PresentationImages/NegFinBW.png "Neg")

# %% [markdown]
# ## Ok! Let's train some more models!

# %%
# Defining a small binary classifier to use in our future tests
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        
        # 2 convolutional layers, one linear
        
        self.conv1 = nn.Conv2d(
            in_channels=1,
            out_channels=64,
            kernel_size=5,
            stride=2,
            padding=2,
            bias=True)

        self.leaky_relu = nn.LeakyReLU()

        self.conv2 = nn.Conv2d(
            in_channels=64,
            out_channels=128,
            kernel_size=5,
            stride=2,
            padding=2,
            bias=True)
        
        # 2 fully connected layers
        self.fc1 = nn.Linear(128*4*4, 1)
        
        self.sigmoid = nn.Sigmoid()
        
    # Forward pass of network
    def forward(self, x):
        # convolutional layer 1 with relu activation
        x = F.relu(self.conv1(x))
        # convolutional layer 2, followed by a 2d pooling layer, with relu activation
        x = F.relu(F.max_pool2d(self.conv2(x), 2))
        # Dropout layer 1
        x = F.dropout(x, p=0.5, training=self.training)
        # Reshape the tensor for the fully connected layers
        x = x.view(-1,128*4*4)
        # Fully connected layer 1 with relu
        x = F.relu(self.fc1(x))
        
        return self.sigmoid(x)

# Fit the model to data
def fit(model, trainLoader, epochs):
    # Define optimizer as Adam
    optimizer = torch.optim.Adam(model.parameters())
    # Define loss function and cross entropy
    loss_func = nn.BCELoss()
    # Start Training
    model.train()
    # Train for the correct number of epochs
    loss_tape = [0]*epochs
    for epoch in range(epochs):
        # This variable tracks how many correct predictions were made in each epoch
        correct = 0
        # Seperate loader into a batch at each step
        for batch_idx, (X_batch, y_batch) in enumerate(trainLoader):
            
            # Convert batch representations to variable floats for input
            X_V = Variable(X_batch).float()
            y_V = Variable(y_batch)
    
            # Zero out the gradients 
            optimizer.zero_grad()
            # Get a prediction from the model
            out = model(X_V)
        
            # Get the loss of the predicted and actual class
            loss = loss_func(out, y_V)
            # Backpropagate the loss
            loss.backward()
            # optimize the gradients using Adam
            optimizer.step()
            
            # Get the prediction and determine if it is correct
            pred = torch.round(out)
            correct += (pred == y_V).sum()
            
            # Print the loss and accuracy at the end of each epoch
            if batch_idx % 999 == 0:
                loss_tape[epoch] = loss.cpu().detach()
                print('Epoch : {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}\t Accuracy:{:.3f}%'.format(
                    epoch, batch_idx*len(X_batch), len(trainLoader.dataset), 100.*batch_idx / len(trainLoader), loss.data.item(), float(correct*100) / float(batchSize*(batch_idx+1))))         
    return loss_tape
# Evaluates data on test data
def evalModel(model, testLoader, full):
    # Counts correct predictions
    correct = 0 
    loss = 0
    loss_func = nn.BCELoss()
    for test_X, test_y in testLoader:
        # Turns batch to variable
        test_X = Variable(test_X).float()
        y_V = Variable(test_y)
        # Gets label prediction
        out = model(test_X)
        pred = torch.round(out)
        
        loss += loss_func(out, y_V)
        # Track corrects
        correct += (pred == test_y).sum()
    # Print accuracy
    print("Test accuracy:  {:.3f}% Avg loss:  {:.3f}".format( (float(correct) / (len(testLoader)*batchSize))*100, (float(loss) / (len(testLoader)))))

# Turns images into tensors, and erases the second half of the data so we can predict it. 
def turnToTensors(fileList, folder, cut=True):
    for i, fileName in enumerate(fileList):
        im = Image.open(folder + fileName)
        if i == 0: 
            imT = transforms.ToTensor()(im)
            if cut:
                imT[:, 16:, :] = 0
            stack = imT[None, :]
        else:
            imT = transforms.ToTensor()(im)
            if cut:
                imT[:, 16:, :] = 0
            stack = torch.cat((stack, imT[None, :]))
    return stack

# %%
# Loading the BTC time series images we made earlier and seperating them into train / test sets with 
# different class balances

dataDir = 'data/FinancialImages/BW/'
listNeg = os.listdir(dataDir +'Neg/')
stackNeg = turnToTensors(listNeg, dataDir +'Neg/')

listPos = os.listdir(dataDir +'Pos/')
stackPos = turnToTensors(listPos, dataDir +'Pos/')

target_ones = torch.ones((len(stackPos), 1))
target_zeros = torch.zeros((len(stackNeg), 1))

# Notice we seperate samples from the past and test on ones from the 'future' 
# from the perspective of the model.

setPos_Train = torch.cat((stackPos[:1100], stackNeg[1000:1100]))
setBal_Train = torch.cat((stackPos[:1100], stackNeg[:1100]))

setNeg_Test = torch.cat((stackPos[1100:1200], stackNeg[1100:1400]))
setBal_Test = torch.cat((stackPos[1100:1400], stackNeg[1100:1400]))

targetsPos_Train = torch.cat((target_ones[:1100], target_zeros[1000:1100]))
targetsBal_Train = torch.cat((target_ones[:1100], target_zeros[:1100]))

targetsNeg_Test = torch.cat((target_ones[1100:1200], target_zeros[1100:1400]))
targetsBal_Test = torch.cat((target_ones[1100:1400], target_zeros[1100:1400]))

dataPos_Train = torch.utils.data.TensorDataset(setPos_Train,targetsPos_Train)
dataBal_Train = torch.utils.data.TensorDataset(setBal_Train,targetsBal_Train)

dataNeg_Test = torch.utils.data.TensorDataset(setNeg_Test,targetsNeg_Test)
dataBal_Test = torch.utils.data.TensorDataset(setBal_Test,targetsBal_Test)

batchSize = 8

trainLoaderPos = torch.utils.data.DataLoader(dataPos_Train, batch_size = batchSize, shuffle = True)
trainLoaderBal = torch.utils.data.DataLoader(dataBal_Train, batch_size = batchSize, shuffle = True)

testLoaderNeg = torch.utils.data.DataLoader(dataNeg_Test, batch_size = batchSize, shuffle = True)
testLoaderBal = torch.utils.data.DataLoader(dataBal_Test, batch_size = batchSize, shuffle = True)

print('Loaded data!')
# Out:
# Loaded data!

# %%
# We only have 2200 total samples to train with! this is really not enough for machine learning. 
print(len(setBal_Train))
# Out:
# 2200

# %% [markdown]
# ## So the idea here is to train this CNN to take the first half of the data (a couple of hours) and then predict if the price will be higher or lower than the starting price by the end of the sample.

# %%
classifierCNN = CNN()

print("Training the model on balanced data:")
print('           -------------------------------------')
print('           -------------------------------------')
print('Architecture of the model:')
print(str(classifierCNN))
print('           -------------------------------------')
lt = fit(classifierCNN, trainLoaderBal, 20)
print('           -------------------------------------')
print('')
print('')


print("Evaluation of model on balanced data:")
print('           -------------------------------------')
evalModel(classifierCNN, testLoaderBal, False)
print('           -------------------------------------')
print('')
print('')

print("Evaluation of model on unbalanced data:")
print('           -------------------------------------')
evalModel(classifierCNN, testLoaderNeg, False)
print('           -------------------------------------')
# Out:
# Training the model on balanced data:
#            -------------------------------------
#            -------------------------------------
# Architecture of the model:
# CNN(
#   (conv1): Conv2d(1, 64, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (leaky_relu): LeakyReLU(negative_slope=0.01)
#   (conv2): Conv2d(64, 128, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
#   (fc1): Linear(in_features=2048, out_features=1, bias=True)
#   (sigmoid): Sigmoid()
# )
#            -------------------------------------
# Epoch : 0 [0/2200 (0%)]	Loss: 0.693147	 Accuracy:37.500%
# Epoch : 1 [0/2200 (0%)]	Loss: 0.305064	 Accuracy:87.500%
# Epoch : 2 [0/2200 (0%)]	Loss: 0.521590	 Accuracy:87.500%
# Epoch : 3 [0/2200 (0%)]	Loss: 0.627431	 Accuracy:50.000%
# Epoch : 4 [0/2200 (0%)]	Loss: 0.544845	 Accuracy:100.000%
# Epoch : 5 [0/2200 (0%)]	Loss: 0.568361	 Accuracy:75.000%
# Epoch : 6 [0/2200 (0%)]	Loss: 0.474942	 Accuracy:87.500%
# Epoch : 7 [0/2200 (0%)]	Loss: 0.610969	 Accuracy:100.000%
# Epoch : 8 [0/2200 (0%)]	Loss: 0.454683	 Accuracy:75.000%
# Epoch : 9 [0/2200 (0%)]	Loss: 0.645648	 Accuracy:75.000%
# Epoch : 10 [0/2200 (0%)]	Loss: 0.366076	 Accuracy:100.000%
# Epoch : 11 [0/2200 (0%)]	Loss: 0.262476	 Accuracy:87.500%
# Epoch : 12 [0/2200 (0%)]	Loss: 0.527221	 Accuracy:87.500%
# Epoch : 13 [0/2200 (0%)]	Loss: 0.457915	 Accuracy:87.500%
# Epoch : 14 [0/2200 (0%)]	Loss: 0.106071	 Accuracy:100.000%
# Epoch : 15 [0/2200 (0%)]	Loss: 0.346984	 Accuracy:87.500%
# Epoch : 16 [0/2200 (0%)]	Loss: 0.613806	 Accuracy:87.500%
# Epoch : 17 [0/2200 (0%)]	Loss: 0.753710	 Accuracy:75.000%
# Epoch : 18 [0/2200 (0%)]	Loss: 0.472951	 Accuracy:87.500%
# Epoch : 19 [0/2200 (0%)]	Loss: 0.472855	 Accuracy:100.000%
#            -------------------------------------
#
#
# Evaluation of model on balanced data:
#            -------------------------------------
# Test accuracy:  83.333% Avg loss:  0.528
#            -------------------------------------
#
#
# Evaluation of model on unbalanced data:
#            -------------------------------------
# Test accuracy:  89.000% Avg loss:  0.675
#            -------------------------------------

# %% [markdown]
# ### Amazing! We will be billionaires in no time!

# %% [markdown]
# ### Not so fast! There are paradigm shifts in finance all the time, lets see what would happen in that scenario. Furthermore, not all coins have the same equal distribution of gain and loss over time. A key usecase for GANs is for fixing unbalanced data or training data that is not the same distribution of classes as it will be in the future / in production.

# %% [markdown]
# ## Here we will train the model on data where most of the samples are increasing, and then test on a balanced set of samples and on one where most samples are decreasing.

# %%
# Balanced dataset class distribution is even
sns.histplot(data=pd.DataFrame(np.array(targetsBal_Train)))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
# Positive training dataset distribution is unbalanced
sns.histplot(data=pd.DataFrame(np.array(targetsPos_Train)))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
# Negative test dataset distribution is unbalanced
sns.histplot(data=pd.DataFrame(np.array(targetsNeg_Test)))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
classifierCNN = CNN()

print("Training the model on unbalanced data:")
print('           -------------------------------------')
print('           -------------------------------------')
fit(classifierCNN, trainLoaderPos, 20)
print('           -------------------------------------')
print('')
print('')


print("Evaluation of model on balanced data:")
print('           -------------------------------------')
evalModel(classifierCNN, testLoaderBal, False)
print('           -------------------------------------')
print('')
print('')

print("Evaluation of model on unbalanced data:")
print('           -------------------------------------')
evalModel(classifierCNN, testLoaderNeg, False)
print('           -------------------------------------')
# Out:
# Training the model on unbalanced data:
#            -------------------------------------
#            -------------------------------------
# Epoch : 0 [0/1200 (0%)]	Loss: 0.691001	 Accuracy:37.500%
# Epoch : 1 [0/1200 (0%)]	Loss: 0.110314	 Accuracy:100.000%
# Epoch : 2 [0/1200 (0%)]	Loss: 0.172787	 Accuracy:100.000%
# Epoch : 3 [0/1200 (0%)]	Loss: 0.661257	 Accuracy:87.500%
# Epoch : 4 [0/1200 (0%)]	Loss: 0.067670	 Accuracy:100.000%
# Epoch : 5 [0/1200 (0%)]	Loss: 0.029519	 Accuracy:100.000%
# Epoch : 6 [0/1200 (0%)]	Loss: 0.141680	 Accuracy:100.000%
# Epoch : 7 [0/1200 (0%)]	Loss: 0.098680	 Accuracy:100.000%
# Epoch : 8 [0/1200 (0%)]	Loss: 0.318027	 Accuracy:87.500%
# Epoch : 9 [0/1200 (0%)]	Loss: 0.012529	 Accuracy:100.000%
# Epoch : 10 [0/1200 (0%)]	Loss: 0.004109	 Accuracy:100.000%
# Epoch : 11 [0/1200 (0%)]	Loss: 0.018174	 Accuracy:100.000%
# Epoch : 12 [0/1200 (0%)]	Loss: 0.175652	 Accuracy:100.000%
# Epoch : 13 [0/1200 (0%)]	Loss: 0.001646	 Accuracy:100.000%
# Epoch : 14 [0/1200 (0%)]	Loss: 0.036104	 Accuracy:100.000%
# Epoch : 15 [0/1200 (0%)]	Loss: 0.284795	 Accuracy:87.500%
# Epoch : 16 [0/1200 (0%)]	Loss: 0.012698	 Accuracy:100.000%
# Epoch : 17 [0/1200 (0%)]	Loss: 0.118215	 Accuracy:100.000%
# Epoch : 18 [0/1200 (0%)]	Loss: 0.263219	 Accuracy:87.500%
# Epoch : 19 [0/1200 (0%)]	Loss: 0.259937	 Accuracy:100.000%
#            -------------------------------------
#
#
# Evaluation of model on balanced data:
#            -------------------------------------
# Test accuracy:  79.667% Avg loss:  1.168
#            -------------------------------------
#
#
# Evaluation of model on unbalanced data:
#            -------------------------------------
# Test accuracy:  71.250% Avg loss:  1.734
#            -------------------------------------

# %% [markdown]
# ## Ok we are seeing a substantial degradation of predictions. So even when the prediction is correct, the model is less sure, which matters a lot because we only want to take sure bets.

# %% [markdown]
# ## Ok let's try to fix this class imbalance using our GAN!

# %%
lt, lv = runGAN(chkpt_name='BTCDemo', dataset='data/FinancialImages/BW/', epochs=500, use_attn=True, size=32, bw=True)
# Out:
# Epoch 1; Elapsed Time = 0s
# 90/97: G=8.168, Dr=0.201, Df=0.193
# Saving Checkpoint...
# Epoch 2; Elapsed Time = 2s
# 90/97: G=5.239, Dr=0.136, Df=0.099
# Epoch 3; Elapsed Time = 4s
# 90/97: G=5.333, Dr=0.148, Df=0.110
# Epoch 4; Elapsed Time = 7s
# 90/97: G=6.096, Dr=0.099, Df=0.068
# Epoch 5; Elapsed Time = 9s
# 90/97: G=6.349, Dr=0.071, Df=0.060
# Epoch 6; Elapsed Time = 12s
# 90/97: G=7.098, Dr=0.096, Df=0.076
# Epoch 7; Elapsed Time = 14s
# 90/97: G=10.015, Dr=0.018, Df=0.017
# Epoch 8; Elapsed Time = 16s
# 90/97: G=7.230, Dr=0.124, Df=0.073
# Epoch 9; Elapsed Time = 19s
# 90/97: G=8.523, Dr=0.030, Df=0.027
# Epoch 10; Elapsed Time = 21s
# 90/97: G=6.091, Dr=0.267, Df=0.185
# Epoch 11; Elapsed Time = 24s
# 90/97: G=4.376, Dr=0.441, Df=0.371
# Saving Checkpoint...
# Epoch 12; Elapsed Time = 27s
# 90/97: G=4.155, Dr=0.327, Df=0.312
# Epoch 13; Elapsed Time = 29s
# 90/97: G=4.078, Dr=0.250, Df=0.235
# Epoch 14; Elapsed Time = 31s
# 90/97: G=4.288, Dr=0.219, Df=0.198
# Epoch 15; Elapsed Time = 34s
# 90/97: G=4.706, Dr=0.197, Df=0.173
# Epoch 16; Elapsed Time = 36s
# 90/97: G=4.666, Dr=0.204, Df=0.194
# Epoch 17; Elapsed Time = 39s
# 90/97: G=4.434, Dr=0.178, Df=0.172
# Epoch 18; Elapsed Time = 41s
# 90/97: G=4.503, Dr=0.184, Df=0.157
# Epoch 19; Elapsed Time = 44s
# 90/97: G=4.964, Dr=0.161, Df=0.147
# Epoch 20; Elapsed Time = 46s
# 90/97: G=4.683, Dr=0.189, Df=0.169
# Epoch 21; Elapsed Time = 49s
# 90/97: G=5.045, Dr=0.135, Df=0.119
# Saving Checkpoint...
# Epoch 22; Elapsed Time = 51s
# 90/97: G=5.243, Dr=0.138, Df=0.123
# Epoch 23; Elapsed Time = 53s
# 90/97: G=5.280, Dr=0.142, Df=0.122
# Epoch 24; Elapsed Time = 56s
# 90/97: G=5.321, Dr=0.123, Df=0.108
# Epoch 25; Elapsed Time = 58s
# 90/97: G=5.453, Dr=0.137, Df=0.121
# Epoch 26; Elapsed Time = 61s
# 90/97: G=6.258, Dr=0.105, Df=0.099
# Epoch 27; Elapsed Time = 63s
# 90/97: G=6.637, Dr=0.081, Df=0.076
# Epoch 28; Elapsed Time = 65s
# 90/97: G=5.977, Dr=0.118, Df=0.110
# Epoch 29; Elapsed Time = 68s
# 90/97: G=5.893, Dr=0.117, Df=0.096
# Epoch 30; Elapsed Time = 70s
# 90/97: G=6.236, Dr=0.092, Df=0.080
# Epoch 31; Elapsed Time = 73s
# 90/97: G=6.397, Dr=0.095, Df=0.087
# Saving Checkpoint...
# Epoch 32; Elapsed Time = 75s
# 90/97: G=6.457, Dr=0.093, Df=0.085
# Epoch 33; Elapsed Time = 78s
# 90/97: G=6.772, Dr=0.087, Df=0.075
# Epoch 34; Elapsed Time = 80s
# 90/97: G=6.408, Dr=0.097, Df=0.080
# Epoch 35; Elapsed Time = 83s
# 90/97: G=6.544, Dr=0.097, Df=0.085
# Epoch 36; Elapsed Time = 85s
# 90/97: G=6.601, Dr=0.087, Df=0.071
# Epoch 37; Elapsed Time = 88s
# 90/97: G=6.680, Dr=0.088, Df=0.076
# Epoch 38; Elapsed Time = 90s
# 90/97: G=6.678, Dr=0.078, Df=0.064
# Epoch 39; Elapsed Time = 93s
# 90/97: G=7.350, Dr=0.064, Df=0.060
# Epoch 40; Elapsed Time = 95s
# 90/97: G=7.575, Dr=0.068, Df=0.063
# Epoch 41; Elapsed Time = 98s
# 90/97: G=7.076, Dr=0.092, Df=0.079
# Saving Checkpoint...
# Epoch 42; Elapsed Time = 100s
# 90/97: G=7.305, Dr=0.072, Df=0.067
# Epoch 43; Elapsed Time = 102s
# 90/97: G=7.011, Dr=0.074, Df=0.078
# Epoch 44; Elapsed Time = 105s
# 90/97: G=7.530, Dr=0.090, Df=0.081
# Epoch 45; Elapsed Time = 107s
# 90/97: G=7.351, Dr=0.074, Df=0.070
# Epoch 46; Elapsed Time = 110s
# 90/97: G=7.303, Dr=0.086, Df=0.076
# Epoch 47; Elapsed Time = 112s
# 90/97: G=7.167, Dr=0.091, Df=0.079
# Epoch 48; Elapsed Time = 115s
# 90/97: G=7.756, Dr=0.054, Df=0.052
# Epoch 49; Elapsed Time = 117s
# 90/97: G=8.555, Dr=0.044, Df=0.041
# Epoch 50; Elapsed Time = 119s
# 90/97: G=7.529, Dr=0.104, Df=0.079
# Epoch 51; Elapsed Time = 122s
# 90/97: G=7.025, Dr=0.072, Df=0.065
# Saving Checkpoint...
# Epoch 52; Elapsed Time = 124s
# 90/97: G=7.093, Dr=0.082, Df=0.082
# Epoch 53; Elapsed Time = 127s
# 90/97: G=7.144, Dr=0.072, Df=0.071
# Epoch 54; Elapsed Time = 129s
# 90/97: G=7.381, Dr=0.063, Df=0.059
# Epoch 55; Elapsed Time = 132s
# 90/97: G=7.198, Dr=0.065, Df=0.053
# Epoch 56; Elapsed Time = 134s
# 90/97: G=7.491, Dr=0.069, Df=0.061
# Epoch 57; Elapsed Time = 137s
# 90/97: G=7.607, Dr=0.075, Df=0.064
# Epoch 58; Elapsed Time = 139s
# 90/97: G=7.665, Dr=0.061, Df=0.058
# Epoch 59; Elapsed Time = 141s
# 90/97: G=7.476, Dr=0.069, Df=0.055
# Epoch 60; Elapsed Time = 144s
# 90/97: G=7.959, Dr=0.044, Df=0.044
# Epoch 61; Elapsed Time = 146s
# 90/97: G=8.358, Dr=0.063, Df=0.057
# Saving Checkpoint...
# Epoch 62; Elapsed Time = 149s
# 90/97: G=8.184, Dr=0.057, Df=0.057
# Epoch 63; Elapsed Time = 151s
# 90/97: G=8.243, Dr=0.063, Df=0.065
# Epoch 64; Elapsed Time = 154s
# 90/97: G=7.812, Dr=0.092, Df=0.093
# Epoch 65; Elapsed Time = 156s
# 90/97: G=7.937, Dr=0.076, Df=0.069
# Epoch 66; Elapsed Time = 159s
# 90/97: G=8.260, Dr=0.066, Df=0.060
# Epoch 67; Elapsed Time = 161s
# 90/97: G=8.416, Dr=0.054, Df=0.065
# Epoch 68; Elapsed Time = 163s
# 90/97: G=8.082, Dr=0.065, Df=0.067
# Epoch 69; Elapsed Time = 166s
# 90/97: G=8.191, Dr=0.057, Df=0.057
# Epoch 70; Elapsed Time = 168s
# 90/97: G=8.413, Dr=0.057, Df=0.049
# Epoch 71; Elapsed Time = 171s
# 90/97: G=8.533, Dr=0.058, Df=0.052
# Saving Checkpoint...
# Epoch 72; Elapsed Time = 173s
# 90/97: G=9.079, Dr=0.057, Df=0.048
# Epoch 73; Elapsed Time = 176s
# 90/97: G=8.318, Dr=0.055, Df=0.055
# Epoch 74; Elapsed Time = 178s
# 90/97: G=8.163, Dr=0.079, Df=0.075
# Epoch 75; Elapsed Time = 181s
# 90/97: G=8.113, Dr=0.075, Df=0.080
# Epoch 76; Elapsed Time = 183s
# 90/97: G=8.595, Dr=0.064, Df=0.057
# Epoch 77; Elapsed Time = 186s
# 90/97: G=7.913, Dr=0.066, Df=0.061
# Epoch 78; Elapsed Time = 188s
# 90/97: G=8.080, Dr=0.055, Df=0.054
# Epoch 79; Elapsed Time = 191s
# 90/97: G=8.899, Dr=0.061, Df=0.063
# Epoch 80; Elapsed Time = 193s
# 90/97: G=8.293, Dr=0.041, Df=0.040
# Epoch 81; Elapsed Time = 196s
# 90/97: G=8.584, Dr=0.051, Df=0.049
# Saving Checkpoint...
# Epoch 82; Elapsed Time = 198s
# 90/97: G=9.311, Dr=0.046, Df=0.043
# Epoch 83; Elapsed Time = 201s
# 90/97: G=9.704, Dr=0.037, Df=0.0388
# Epoch 84; Elapsed Time = 203s
# 90/97: G=9.872, Dr=0.045, Df=0.0454
# Epoch 85; Elapsed Time = 205s
# 90/97: G=8.635, Dr=0.055, Df=0.053
# Epoch 86; Elapsed Time = 208s
# 90/97: G=9.692, Dr=0.036, Df=0.036
# Epoch 87; Elapsed Time = 210s
# 90/97: G=9.200, Dr=0.055, Df=0.052
# Epoch 88; Elapsed Time = 213s
# 90/97: G=8.816, Dr=0.060, Df=0.060
# Epoch 89; Elapsed Time = 215s
# 90/97: G=9.083, Dr=0.056, Df=0.052
# Epoch 90; Elapsed Time = 218s
# 90/97: G=8.658, Dr=0.070, Df=0.063
# Epoch 91; Elapsed Time = 220s
# 90/97: G=8.329, Dr=0.056, Df=0.047
# Saving Checkpoint...
# Epoch 92; Elapsed Time = 223s
# 90/97: G=8.915, Dr=0.056, Df=0.050
# Epoch 93; Elapsed Time = 225s
# 90/97: G=8.946, Dr=0.064, Df=0.068
# Epoch 94; Elapsed Time = 227s
# 90/97: G=8.340, Dr=0.057, Df=0.057
# Epoch 95; Elapsed Time = 230s
# 90/97: G=8.761, Dr=0.050, Df=0.047
# Epoch 96; Elapsed Time = 232s
# 90/97: G=9.000, Dr=0.065, Df=0.061
# Epoch 97; Elapsed Time = 235s
# 90/97: G=8.911, Dr=0.048, Df=0.056
# Epoch 98; Elapsed Time = 237s
# 90/97: G=9.393, Dr=0.059, Df=0.059
# Epoch 99; Elapsed Time = 240s
# 90/97: G=9.608, Dr=0.047, Df=0.051
# Epoch 100; Elapsed Time = 242s
# 90/97: G=8.963, Dr=0.072, Df=0.072
# Epoch 101; Elapsed Time = 244s
# 90/97: G=9.471, Dr=0.057, Df=0.065
# Saving Checkpoint...
# Epoch 102; Elapsed Time = 247s
# 90/97: G=8.948, Dr=0.045, Df=0.043
# Epoch 103; Elapsed Time = 249s
# 90/97: G=8.805, Dr=0.075, Df=0.0622
# Epoch 104; Elapsed Time = 252s
# 90/97: G=8.903, Dr=0.042, Df=0.043
# Epoch 105; Elapsed Time = 254s
# 90/97: G=9.477, Dr=0.043, Df=0.044
# Epoch 106; Elapsed Time = 256s
# 90/97: G=9.550, Dr=0.070, Df=0.0677
# Epoch 107; Elapsed Time = 259s
# 90/97: G=9.185, Dr=0.062, Df=0.067
# Epoch 108; Elapsed Time = 261s
# 90/97: G=9.461, Dr=0.062, Df=0.065
# Epoch 109; Elapsed Time = 264s
# 90/97: G=8.898, Dr=0.062, Df=0.059
# Epoch 110; Elapsed Time = 266s
# 90/97: G=9.135, Dr=0.061, Df=0.058
# Epoch 111; Elapsed Time = 269s
# 90/97: G=9.751, Dr=0.031, Df=0.032
# Saving Checkpoint...
# Epoch 112; Elapsed Time = 271s
# 90/97: G=9.181, Dr=0.064, Df=0.060
# Epoch 113; Elapsed Time = 274s
# 90/97: G=9.278, Dr=0.057, Df=0.054
# Epoch 114; Elapsed Time = 276s
# 90/97: G=9.210, Dr=0.053, Df=0.054
# Epoch 115; Elapsed Time = 278s
# 90/97: G=8.729, Dr=0.059, Df=0.062
# Epoch 116; Elapsed Time = 281s
# 90/97: G=8.380, Dr=0.057, Df=0.060
# Epoch 117; Elapsed Time = 283s
# 90/97: G=9.150, Dr=0.042, Df=0.042
# Epoch 118; Elapsed Time = 286s
# 90/97: G=9.497, Dr=0.035, Df=0.039
# Epoch 119; Elapsed Time = 288s
# 90/97: G=9.839, Dr=0.036, Df=0.0323
# Epoch 120; Elapsed Time = 291s
# 90/97: G=9.604, Dr=0.042, Df=0.0444
# Epoch 121; Elapsed Time = 293s
# 90/97: G=9.974, Dr=0.040, Df=0.0389
# Saving Checkpoint...
# Epoch 122; Elapsed Time = 296s
# 90/97: G=9.943, Dr=0.026, Df=0.0245
# Epoch 123; Elapsed Time = 298s
# 90/97: G=9.564, Dr=0.041, Df=0.0351
# Epoch 124; Elapsed Time = 300s
# 90/97: G=9.843, Dr=0.066, Df=0.0573
# Epoch 125; Elapsed Time = 303s
# 90/97: G=9.349, Dr=0.061, Df=0.055
# Epoch 126; Elapsed Time = 305s
# 90/97: G=9.252, Dr=0.038, Df=0.041
# Epoch 127; Elapsed Time = 307s
# 90/97: G=9.351, Dr=0.046, Df=0.045
# Epoch 128; Elapsed Time = 310s
# 90/97: G=9.900, Dr=0.049, Df=0.0443
# Epoch 129; Elapsed Time = 312s
# 90/97: G=10.503, Dr=0.059, Df=0.053
# Epoch 130; Elapsed Time = 315s
# 90/97: G=9.936, Dr=0.062, Df=0.0580
# Epoch 131; Elapsed Time = 317s
# 90/97: G=9.572, Dr=0.043, Df=0.042
# Saving Checkpoint...
# Epoch 132; Elapsed Time = 320s
# 90/97: G=10.660, Dr=0.028, Df=0.038
# Epoch 133; Elapsed Time = 322s
# 90/97: G=10.247, Dr=0.046, Df=0.044
# Epoch 134; Elapsed Time = 325s
# 90/97: G=9.936, Dr=0.057, Df=0.0596
# Epoch 135; Elapsed Time = 327s
# 90/97: G=9.476, Dr=0.053, Df=0.054
# Epoch 136; Elapsed Time = 330s
# 90/97: G=10.255, Dr=0.065, Df=0.050
# Epoch 137; Elapsed Time = 332s
# 90/97: G=10.004, Dr=0.048, Df=0.045
# Epoch 138; Elapsed Time = 334s
# 90/97: G=9.764, Dr=0.039, Df=0.0425
# Epoch 139; Elapsed Time = 337s
# 90/97: G=9.774, Dr=0.018, Df=0.021
# Epoch 140; Elapsed Time = 339s
# 90/97: G=11.151, Dr=0.045, Df=0.042
# Epoch 141; Elapsed Time = 342s
# 90/97: G=10.046, Dr=0.039, Df=0.036
# Saving Checkpoint...
# Epoch 142; Elapsed Time = 344s
# 90/97: G=10.553, Dr=0.050, Df=0.050
# Epoch 143; Elapsed Time = 346s
# 90/97: G=10.707, Dr=0.051, Df=0.055
# Epoch 144; Elapsed Time = 349s
# 90/97: G=9.748, Dr=0.035, Df=0.038
# Epoch 145; Elapsed Time = 351s
# 90/97: G=10.439, Dr=0.037, Df=0.038
# Epoch 146; Elapsed Time = 354s
# 90/97: G=10.417, Dr=0.026, Df=0.024
# Epoch 147; Elapsed Time = 356s
# 90/97: G=10.607, Dr=0.053, Df=0.042
# Epoch 148; Elapsed Time = 359s
# 90/97: G=10.570, Dr=0.030, Df=0.032
# Epoch 149; Elapsed Time = 361s
# 90/97: G=11.435, Dr=0.053, Df=0.049
# Epoch 150; Elapsed Time = 364s
# 90/97: G=10.768, Dr=0.028, Df=0.032
# Epoch 151; Elapsed Time = 366s
# 90/97: G=11.038, Dr=0.047, Df=0.040
# Saving Checkpoint...
# Epoch 152; Elapsed Time = 368s
# 90/97: G=10.382, Dr=0.041, Df=0.038
# Epoch 153; Elapsed Time = 371s
# 90/97: G=10.371, Dr=0.054, Df=0.042
# Epoch 154; Elapsed Time = 373s
# 90/97: G=10.253, Dr=0.054, Df=0.046
# Epoch 155; Elapsed Time = 376s
# 90/97: G=10.456, Dr=0.044, Df=0.045
# Epoch 156; Elapsed Time = 378s
# 90/97: G=10.080, Dr=0.042, Df=0.042
# Epoch 157; Elapsed Time = 380s
# 90/97: G=10.365, Dr=0.039, Df=0.042
# Epoch 158; Elapsed Time = 383s
# 90/97: G=10.217, Dr=0.046, Df=0.043
# Epoch 159; Elapsed Time = 385s
# 90/97: G=10.169, Dr=0.070, Df=0.058
# Epoch 160; Elapsed Time = 388s
# 90/97: G=10.306, Dr=0.047, Df=0.046
# Epoch 161; Elapsed Time = 390s
# 90/97: G=9.538, Dr=0.062, Df=0.059
# Saving Checkpoint...
# Epoch 162; Elapsed Time = 393s
# 90/97: G=9.717, Dr=0.055, Df=0.047
# Epoch 163; Elapsed Time = 395s
# 90/97: G=9.832, Dr=0.035, Df=0.039
# Epoch 164; Elapsed Time = 397s
# 90/97: G=10.309, Dr=0.043, Df=0.046
# Epoch 165; Elapsed Time = 400s
# 90/97: G=10.677, Dr=0.042, Df=0.042
# Epoch 166; Elapsed Time = 402s
# 90/97: G=10.232, Dr=0.057, Df=0.053
# Epoch 167; Elapsed Time = 404s
# 90/97: G=9.642, Dr=0.044, Df=0.0477
# Epoch 168; Elapsed Time = 407s
# 90/97: G=10.245, Dr=0.041, Df=0.038
# Epoch 169; Elapsed Time = 409s
# 90/97: G=10.672, Dr=0.051, Df=0.056
# Epoch 170; Elapsed Time = 412s
# 90/97: G=10.601, Dr=0.038, Df=0.034
# Epoch 171; Elapsed Time = 414s
# 90/97: G=10.015, Dr=0.057, Df=0.050
# Saving Checkpoint...
# Epoch 172; Elapsed Time = 417s
# 90/97: G=10.087, Dr=0.046, Df=0.042
# Epoch 173; Elapsed Time = 419s
# 90/97: G=10.121, Dr=0.047, Df=0.047
# Epoch 174; Elapsed Time = 422s
# 90/97: G=10.470, Dr=0.045, Df=0.046
# Epoch 175; Elapsed Time = 424s
# 90/97: G=9.686, Dr=0.046, Df=0.049
# Epoch 176; Elapsed Time = 427s
# 90/97: G=9.713, Dr=0.066, Df=0.0582
# Epoch 177; Elapsed Time = 429s
# 90/97: G=9.580, Dr=0.024, Df=0.0220
# Epoch 178; Elapsed Time = 432s
# 90/97: G=10.291, Dr=0.037, Df=0.030
# Epoch 179; Elapsed Time = 434s
# 90/97: G=10.146, Dr=0.048, Df=0.046
# Epoch 180; Elapsed Time = 436s
# 90/97: G=10.330, Dr=0.023, Df=0.024
# Epoch 181; Elapsed Time = 439s
# 90/97: G=10.570, Dr=0.029, Df=0.028
# Saving Checkpoint...
# Epoch 182; Elapsed Time = 441s
# 90/97: G=11.555, Dr=0.031, Df=0.033
# Epoch 183; Elapsed Time = 443s
# 90/97: G=10.822, Dr=0.028, Df=0.029
# Epoch 184; Elapsed Time = 446s
# 90/97: G=10.608, Dr=0.051, Df=0.045
# Epoch 185; Elapsed Time = 448s
# 90/97: G=11.139, Dr=0.033, Df=0.032
# Epoch 186; Elapsed Time = 451s
# 90/97: G=11.238, Dr=0.035, Df=0.039
# Epoch 187; Elapsed Time = 453s
# 90/97: G=11.087, Dr=0.030, Df=0.026
# Epoch 188; Elapsed Time = 455s
# 90/97: G=11.435, Dr=0.034, Df=0.032
# Epoch 189; Elapsed Time = 458s
# 90/97: G=10.765, Dr=0.036, Df=0.040
# Epoch 190; Elapsed Time = 460s
# 90/97: G=10.181, Dr=0.051, Df=0.052
# Epoch 191; Elapsed Time = 462s
# 90/97: G=10.165, Dr=0.056, Df=0.057
# Saving Checkpoint...
# Epoch 192; Elapsed Time = 465s
# 90/97: G=11.364, Dr=0.032, Df=0.033
# Epoch 193; Elapsed Time = 467s
# 90/97: G=11.682, Dr=0.036, Df=0.038
# Epoch 194; Elapsed Time = 470s
# 90/97: G=9.925, Dr=0.036, Df=0.0374
# Epoch 195; Elapsed Time = 472s
# 90/97: G=10.490, Dr=0.039, Df=0.043
# Epoch 196; Elapsed Time = 475s
# 90/97: G=10.046, Dr=0.036, Df=0.031
# Epoch 197; Elapsed Time = 477s
# 90/97: G=10.045, Dr=0.040, Df=0.035
# Epoch 198; Elapsed Time = 480s
# 90/97: G=11.059, Dr=0.039, Df=0.042
# Epoch 199; Elapsed Time = 482s
# 90/97: G=10.399, Dr=0.051, Df=0.045
# Epoch 200; Elapsed Time = 485s
# 90/97: G=10.753, Dr=0.029, Df=0.030
# Epoch 201; Elapsed Time = 487s
# 90/97: G=11.275, Dr=0.028, Df=0.031
# Saving Checkpoint...
# Epoch 202; Elapsed Time = 490s
# 90/97: G=10.963, Dr=0.041, Df=0.035
# Epoch 203; Elapsed Time = 492s
# 90/97: G=10.563, Dr=0.039, Df=0.030
# Epoch 204; Elapsed Time = 494s
# 90/97: G=10.962, Dr=0.035, Df=0.031
# Epoch 205; Elapsed Time = 497s
# 90/97: G=10.654, Dr=0.046, Df=0.047
# Epoch 206; Elapsed Time = 499s
# 90/97: G=10.361, Dr=0.051, Df=0.052
# Epoch 207; Elapsed Time = 502s
# 90/97: G=10.501, Dr=0.040, Df=0.038
# Epoch 208; Elapsed Time = 504s
# 90/97: G=10.617, Dr=0.030, Df=0.036
# Epoch 209; Elapsed Time = 507s
# 90/97: G=10.899, Dr=0.026, Df=0.027
# Epoch 210; Elapsed Time = 509s
# 90/97: G=11.116, Dr=0.039, Df=0.045
# Epoch 211; Elapsed Time = 511s
# 90/97: G=11.014, Dr=0.040, Df=0.036
# Saving Checkpoint...
# Epoch 212; Elapsed Time = 514s
# 90/97: G=10.788, Dr=0.049, Df=0.040
# Epoch 213; Elapsed Time = 516s
# 90/97: G=10.296, Dr=0.031, Df=0.032
# Epoch 214; Elapsed Time = 519s
# 90/97: G=10.592, Dr=0.040, Df=0.033
# Epoch 215; Elapsed Time = 521s
# 90/97: G=10.711, Dr=0.038, Df=0.031
# Epoch 216; Elapsed Time = 523s
# 90/97: G=10.653, Dr=0.035, Df=0.039
# Epoch 217; Elapsed Time = 526s
# 90/97: G=10.511, Dr=0.042, Df=0.046
# Epoch 218; Elapsed Time = 528s
# 90/97: G=11.290, Dr=0.033, Df=0.029
# Epoch 219; Elapsed Time = 531s
# 90/97: G=10.732, Dr=0.057, Df=0.046
# Epoch 220; Elapsed Time = 533s
# 90/97: G=9.817, Dr=0.047, Df=0.0432
# Epoch 221; Elapsed Time = 536s
# 90/97: G=9.750, Dr=0.036, Df=0.0346
# Saving Checkpoint...
# Epoch 222; Elapsed Time = 538s
# 90/97: G=10.617, Dr=0.045, Df=0.035
# Epoch 223; Elapsed Time = 541s
# 90/97: G=10.672, Dr=0.042, Df=0.041
# Epoch 224; Elapsed Time = 543s
# 90/97: G=10.814, Dr=0.034, Df=0.032
# Epoch 225; Elapsed Time = 545s
# 90/97: G=10.640, Dr=0.031, Df=0.037
# Epoch 226; Elapsed Time = 548s
# 90/97: G=10.171, Dr=0.054, Df=0.044
# Epoch 227; Elapsed Time = 550s
# 90/97: G=10.555, Dr=0.031, Df=0.032
# Epoch 228; Elapsed Time = 553s
# 90/97: G=10.939, Dr=0.037, Df=0.033
# Epoch 229; Elapsed Time = 555s
# 90/97: G=11.333, Dr=0.043, Df=0.049
# Epoch 230; Elapsed Time = 557s
# 90/97: G=10.560, Dr=0.037, Df=0.035
# Epoch 231; Elapsed Time = 560s
# 90/97: G=10.945, Dr=0.033, Df=0.037
# Saving Checkpoint...
# Epoch 232; Elapsed Time = 562s
# 90/97: G=11.659, Dr=0.031, Df=0.033
# Epoch 233; Elapsed Time = 565s
# 90/97: G=10.779, Dr=0.035, Df=0.034
# Epoch 234; Elapsed Time = 567s
# 90/97: G=10.650, Dr=0.038, Df=0.038
# Epoch 235; Elapsed Time = 570s
# 90/97: G=10.373, Dr=0.040, Df=0.042
# Epoch 236; Elapsed Time = 572s
# 90/97: G=10.514, Dr=0.052, Df=0.054
# Epoch 237; Elapsed Time = 574s
# 90/97: G=10.579, Dr=0.053, Df=0.047
# Epoch 238; Elapsed Time = 577s
# 90/97: G=10.288, Dr=0.044, Df=0.046
# Epoch 239; Elapsed Time = 579s
# 90/97: G=10.546, Dr=0.033, Df=0.030
# Epoch 240; Elapsed Time = 582s
# 90/97: G=10.345, Dr=0.042, Df=0.043
# Epoch 241; Elapsed Time = 584s
# 90/97: G=10.847, Dr=0.037, Df=0.031
# Saving Checkpoint...
# Epoch 242; Elapsed Time = 587s
# 90/97: G=10.447, Dr=0.034, Df=0.036
# Epoch 243; Elapsed Time = 589s
# 90/97: G=11.089, Dr=0.041, Df=0.039
# Epoch 244; Elapsed Time = 591s
# 90/97: G=10.468, Dr=0.041, Df=0.042
# Epoch 245; Elapsed Time = 594s
# 90/97: G=10.255, Dr=0.043, Df=0.045
# Epoch 246; Elapsed Time = 596s
# 90/97: G=10.359, Dr=0.032, Df=0.031
# Epoch 247; Elapsed Time = 598s
# 90/97: G=10.093, Dr=0.017, Df=0.018
# Epoch 248; Elapsed Time = 601s
# 90/97: G=11.002, Dr=0.034, Df=0.031
# Epoch 249; Elapsed Time = 603s
# 90/97: G=10.843, Dr=0.040, Df=0.041
# Epoch 250; Elapsed Time = 606s
# 90/97: G=10.778, Dr=0.032, Df=0.026
# Epoch 251; Elapsed Time = 608s
# 90/97: G=10.876, Dr=0.037, Df=0.035
# Saving Checkpoint...
# Epoch 252; Elapsed Time = 610s
# 90/97: G=10.822, Dr=0.046, Df=0.044
# Epoch 253; Elapsed Time = 613s
# 90/97: G=10.424, Dr=0.040, Df=0.042
# Epoch 254; Elapsed Time = 615s
# 90/97: G=10.503, Dr=0.032, Df=0.037
# Epoch 255; Elapsed Time = 618s
# 90/97: G=10.570, Dr=0.040, Df=0.041
# Epoch 256; Elapsed Time = 620s
# 90/97: G=10.985, Dr=0.048, Df=0.044
# Epoch 257; Elapsed Time = 623s
# 90/97: G=10.844, Dr=0.037, Df=0.035
# Epoch 258; Elapsed Time = 625s
# 90/97: G=11.093, Dr=0.031, Df=0.026
# Epoch 259; Elapsed Time = 627s
# 90/97: G=10.743, Dr=0.027, Df=0.029
# Epoch 260; Elapsed Time = 630s
# 90/97: G=11.849, Dr=0.035, Df=0.029
# Epoch 261; Elapsed Time = 632s
# 90/97: G=11.419, Dr=0.027, Df=0.025
# Saving Checkpoint...
# Epoch 262; Elapsed Time = 635s
# 90/97: G=10.624, Dr=0.044, Df=0.042
# Epoch 263; Elapsed Time = 637s
# 90/97: G=10.686, Dr=0.028, Df=0.024
# Epoch 264; Elapsed Time = 640s
# 90/97: G=11.492, Dr=0.041, Df=0.038
# Epoch 265; Elapsed Time = 642s
# 90/97: G=11.193, Dr=0.035, Df=0.030
# Epoch 266; Elapsed Time = 645s
# 90/97: G=10.923, Dr=0.034, Df=0.031
# Epoch 267; Elapsed Time = 647s
# 90/97: G=11.683, Dr=0.032, Df=0.035
# Epoch 268; Elapsed Time = 650s
# 90/97: G=10.663, Dr=0.033, Df=0.026
# Epoch 269; Elapsed Time = 652s
# 90/97: G=10.221, Dr=0.052, Df=0.047
# Epoch 270; Elapsed Time = 654s
# 90/97: G=10.275, Dr=0.044, Df=0.036
# Epoch 271; Elapsed Time = 657s
# 90/97: G=10.568, Dr=0.023, Df=0.024
# Saving Checkpoint...
# Epoch 272; Elapsed Time = 659s
# 90/97: G=11.150, Dr=0.044, Df=0.045
# Epoch 273; Elapsed Time = 662s
# 90/97: G=10.723, Dr=0.021, Df=0.021
# Epoch 274; Elapsed Time = 664s
# 90/97: G=11.033, Dr=0.018, Df=0.021
# Epoch 275; Elapsed Time = 666s
# 90/97: G=11.840, Dr=0.032, Df=0.032
# Epoch 276; Elapsed Time = 669s
# 90/97: G=11.246, Dr=0.036, Df=0.034
# Epoch 277; Elapsed Time = 671s
# 90/97: G=11.659, Dr=0.031, Df=0.025
# Epoch 278; Elapsed Time = 674s
# 90/97: G=11.283, Dr=0.033, Df=0.033
# Epoch 279; Elapsed Time = 676s
# 90/97: G=11.378, Dr=0.024, Df=0.031
# Epoch 280; Elapsed Time = 679s
# 90/97: G=11.272, Dr=0.042, Df=0.050
# Epoch 281; Elapsed Time = 681s
# 90/97: G=11.519, Dr=0.029, Df=0.036
# Saving Checkpoint...
# Epoch 282; Elapsed Time = 683s
# 90/97: G=11.798, Dr=0.029, Df=0.032
# Epoch 283; Elapsed Time = 686s
# 90/97: G=11.496, Dr=0.027, Df=0.031
# Epoch 284; Elapsed Time = 688s
# 90/97: G=11.478, Dr=0.046, Df=0.050
# Epoch 285; Elapsed Time = 691s
# 90/97: G=11.099, Dr=0.040, Df=0.041
# Epoch 286; Elapsed Time = 693s
# 90/97: G=11.252, Dr=0.039, Df=0.036
# Epoch 287; Elapsed Time = 696s
# 90/97: G=11.283, Dr=0.041, Df=0.040
# Epoch 288; Elapsed Time = 698s
# 90/97: G=10.860, Dr=0.029, Df=0.027
# Epoch 289; Elapsed Time = 700s
# 90/97: G=11.768, Dr=0.041, Df=0.036
# Epoch 290; Elapsed Time = 703s
# 90/97: G=11.115, Dr=0.036, Df=0.037
# Epoch 291; Elapsed Time = 705s
# 90/97: G=10.712, Dr=0.025, Df=0.030
# Saving Checkpoint...
# Epoch 292; Elapsed Time = 708s
# 90/97: G=11.063, Dr=0.042, Df=0.031
# Epoch 293; Elapsed Time = 710s
# 90/97: G=11.163, Dr=0.030, Df=0.029
# Epoch 294; Elapsed Time = 713s
# 90/97: G=11.072, Dr=0.052, Df=0.045
# Epoch 295; Elapsed Time = 715s
# 90/97: G=10.872, Dr=0.037, Df=0.037
# Epoch 296; Elapsed Time = 718s
# 90/97: G=11.917, Dr=0.033, Df=0.042
# Epoch 297; Elapsed Time = 720s
# 90/97: G=11.632, Dr=0.042, Df=0.047
# Epoch 298; Elapsed Time = 723s
# 90/97: G=13.511, Dr=0.043, Df=0.036
# Epoch 299; Elapsed Time = 725s
# 90/97: G=11.350, Dr=0.043, Df=0.040
# Epoch 300; Elapsed Time = 727s
# 90/97: G=10.491, Dr=0.048, Df=0.041
# Epoch 301; Elapsed Time = 730s
# 90/97: G=11.023, Dr=0.041, Df=0.041
# Saving Checkpoint...
# Epoch 302; Elapsed Time = 732s
# 90/97: G=11.055, Dr=0.049, Df=0.044
# Epoch 303; Elapsed Time = 735s
# 90/97: G=11.179, Dr=0.037, Df=0.039
# Epoch 304; Elapsed Time = 737s
# 90/97: G=11.254, Dr=0.049, Df=0.043
# Epoch 305; Elapsed Time = 739s
# 90/97: G=10.568, Dr=0.019, Df=0.025
# Epoch 306; Elapsed Time = 742s
# 90/97: G=10.868, Dr=0.030, Df=0.029
# Epoch 307; Elapsed Time = 744s
# 90/97: G=10.677, Dr=0.044, Df=0.026
# Epoch 308; Elapsed Time = 747s
# 90/97: G=11.164, Dr=0.048, Df=0.043
# Epoch 309; Elapsed Time = 749s
# 90/97: G=11.000, Dr=0.052, Df=0.044
# Epoch 310; Elapsed Time = 752s
# 90/97: G=10.835, Dr=0.027, Df=0.034
# Epoch 311; Elapsed Time = 754s
# 90/97: G=10.994, Dr=0.033, Df=0.031
# Saving Checkpoint...
# Epoch 312; Elapsed Time = 756s
# 90/97: G=10.493, Dr=0.048, Df=0.045
# Epoch 313; Elapsed Time = 759s
# 90/97: G=10.009, Dr=0.027, Df=0.030
# Epoch 314; Elapsed Time = 761s
# 90/97: G=10.706, Dr=0.042, Df=0.040
# Epoch 315; Elapsed Time = 764s
# 90/97: G=10.530, Dr=0.043, Df=0.042
# Epoch 316; Elapsed Time = 766s
# 90/97: G=10.610, Dr=0.037, Df=0.038
# Epoch 317; Elapsed Time = 769s
# 90/97: G=10.831, Dr=0.035, Df=0.034
# Epoch 318; Elapsed Time = 771s
# 90/97: G=11.091, Dr=0.036, Df=0.032
# Epoch 319; Elapsed Time = 774s
# 90/97: G=11.478, Dr=0.037, Df=0.034
# Epoch 320; Elapsed Time = 776s
# 90/97: G=11.246, Dr=0.037, Df=0.033
# Epoch 321; Elapsed Time = 778s
# 90/97: G=11.198, Dr=0.032, Df=0.025
# Saving Checkpoint...
# Epoch 322; Elapsed Time = 781s
# 90/97: G=11.239, Dr=0.019, Df=0.019
# Epoch 323; Elapsed Time = 783s
# 90/97: G=11.583, Dr=0.029, Df=0.026
# Epoch 324; Elapsed Time = 786s
# 90/97: G=10.922, Dr=0.028, Df=0.021
# Epoch 325; Elapsed Time = 788s
# 90/97: G=11.045, Dr=0.028, Df=0.030
# Epoch 326; Elapsed Time = 791s
# 90/97: G=11.151, Dr=0.037, Df=0.030
# Epoch 327; Elapsed Time = 793s
# 90/97: G=11.522, Dr=0.024, Df=0.024
# Epoch 328; Elapsed Time = 796s
# 90/97: G=11.716, Dr=0.039, Df=0.037
# Epoch 329; Elapsed Time = 798s
# 90/97: G=10.605, Dr=0.039, Df=0.037
# Epoch 330; Elapsed Time = 800s
# 90/97: G=10.248, Dr=0.059, Df=0.050
# Epoch 331; Elapsed Time = 803s
# 90/97: G=10.606, Dr=0.037, Df=0.039
# Saving Checkpoint...
# Epoch 332; Elapsed Time = 805s
# 90/97: G=11.022, Dr=0.049, Df=0.041
# Epoch 333; Elapsed Time = 808s
# 90/97: G=10.843, Dr=0.031, Df=0.042
# Epoch 334; Elapsed Time = 810s
# 90/97: G=11.692, Dr=0.038, Df=0.044
# Epoch 335; Elapsed Time = 812s
# 90/97: G=10.449, Dr=0.054, Df=0.053
# Epoch 336; Elapsed Time = 815s
# 90/97: G=10.515, Dr=0.041, Df=0.035
# Epoch 337; Elapsed Time = 817s
# 90/97: G=10.693, Dr=0.036, Df=0.037
# Epoch 338; Elapsed Time = 820s
# 90/97: G=10.677, Dr=0.034, Df=0.035
# Epoch 339; Elapsed Time = 822s
# 90/97: G=11.101, Dr=0.028, Df=0.032
# Epoch 340; Elapsed Time = 825s
# 90/97: G=11.116, Dr=0.038, Df=0.036
# Epoch 341; Elapsed Time = 827s
# 90/97: G=11.503, Dr=0.036, Df=0.036
# Saving Checkpoint...
# Epoch 342; Elapsed Time = 830s
# 90/97: G=11.080, Dr=0.037, Df=0.030
# Epoch 343; Elapsed Time = 832s
# 90/97: G=11.074, Dr=0.042, Df=0.043
# Epoch 344; Elapsed Time = 835s
# 90/97: G=11.042, Dr=0.042, Df=0.037
# Epoch 345; Elapsed Time = 837s
# 90/97: G=11.264, Dr=0.031, Df=0.033
# Epoch 346; Elapsed Time = 840s
# 90/97: G=11.177, Dr=0.037, Df=0.034
# Epoch 347; Elapsed Time = 842s
# 90/97: G=11.361, Dr=0.031, Df=0.029
# Epoch 348; Elapsed Time = 844s
# 90/97: G=10.705, Dr=0.020, Df=0.017
# Epoch 349; Elapsed Time = 847s
# 90/97: G=11.637, Dr=0.019, Df=0.017
# Epoch 350; Elapsed Time = 849s
# 90/97: G=11.556, Dr=0.032, Df=0.032
# Epoch 351; Elapsed Time = 852s
# 90/97: G=11.703, Dr=0.034, Df=0.030
# Saving Checkpoint...
# Epoch 352; Elapsed Time = 854s
# 90/97: G=11.374, Dr=0.044, Df=0.043
# Epoch 353; Elapsed Time = 857s
# 90/97: G=11.563, Dr=0.041, Df=0.040
# Epoch 354; Elapsed Time = 859s
# 90/97: G=11.079, Dr=0.047, Df=0.035
# Epoch 355; Elapsed Time = 862s
# 90/97: G=10.751, Dr=0.049, Df=0.044
# Epoch 356; Elapsed Time = 864s
# 90/97: G=10.874, Dr=0.039, Df=0.039
# Epoch 357; Elapsed Time = 867s
# 90/97: G=10.936, Dr=0.029, Df=0.026
# Epoch 358; Elapsed Time = 869s
# 90/97: G=11.151, Dr=0.044, Df=0.035
# Epoch 359; Elapsed Time = 872s
# 90/97: G=11.365, Dr=0.026, Df=0.023
# Epoch 360; Elapsed Time = 874s
# 90/97: G=11.039, Dr=0.041, Df=0.034
# Epoch 361; Elapsed Time = 876s
# 90/97: G=11.044, Dr=0.031, Df=0.027
# Saving Checkpoint...
# Epoch 362; Elapsed Time = 879s
# 90/97: G=11.339, Dr=0.025, Df=0.021
# Epoch 363; Elapsed Time = 881s
# 90/97: G=11.299, Dr=0.038, Df=0.034
# Epoch 364; Elapsed Time = 884s
# 90/97: G=11.429, Dr=0.025, Df=0.028
# Epoch 365; Elapsed Time = 886s
# 90/97: G=11.562, Dr=0.044, Df=0.042
# Epoch 366; Elapsed Time = 889s
# 90/97: G=11.133, Dr=0.041, Df=0.039
# Epoch 367; Elapsed Time = 891s
# 90/97: G=11.540, Dr=0.041, Df=0.037
# Epoch 368; Elapsed Time = 893s
# 90/97: G=11.448, Dr=0.032, Df=0.037
# Epoch 369; Elapsed Time = 896s
# 90/97: G=10.753, Dr=0.055, Df=0.046
# Epoch 370; Elapsed Time = 898s
# 90/97: G=11.169, Dr=0.038, Df=0.041
# Epoch 371; Elapsed Time = 901s
# 90/97: G=14.549, Dr=0.020, Df=0.020
# Saving Checkpoint...
# Epoch 372; Elapsed Time = 903s
# 90/97: G=13.491, Dr=0.011, Df=0.013
# Epoch 373; Elapsed Time = 905s
# 90/97: G=13.539, Dr=0.019, Df=0.018
# Epoch 374; Elapsed Time = 908s
# 90/97: G=12.726, Dr=0.039, Df=0.033
# Epoch 375; Elapsed Time = 910s
# 90/97: G=13.090, Dr=0.018, Df=0.022
# Epoch 376; Elapsed Time = 912s
# 90/97: G=13.782, Dr=0.010, Df=0.009
# Epoch 377; Elapsed Time = 915s
# 90/97: G=12.662, Dr=0.026, Df=0.027
# Epoch 378; Elapsed Time = 917s
# 90/97: G=11.978, Dr=0.032, Df=0.028
# Epoch 379; Elapsed Time = 920s
# 90/97: G=11.765, Dr=0.027, Df=0.029
# Epoch 380; Elapsed Time = 922s
# 90/97: G=12.122, Dr=0.041, Df=0.040
# Epoch 381; Elapsed Time = 925s
# 90/97: G=11.349, Dr=0.041, Df=0.044
# Saving Checkpoint...
# Epoch 382; Elapsed Time = 927s
# 90/97: G=11.923, Dr=0.031, Df=0.038
# Epoch 383; Elapsed Time = 929s
# 90/97: G=11.389, Dr=0.031, Df=0.027
# Epoch 384; Elapsed Time = 932s
# 90/97: G=12.084, Dr=0.030, Df=0.031
# Epoch 385; Elapsed Time = 934s
# 90/97: G=12.290, Dr=0.038, Df=0.035
# Epoch 386; Elapsed Time = 937s
# 90/97: G=11.682, Dr=0.039, Df=0.041
# Epoch 387; Elapsed Time = 939s
# 90/97: G=11.214, Dr=0.042, Df=0.032
# Epoch 388; Elapsed Time = 942s
# 90/97: G=11.107, Dr=0.030, Df=0.034
# Epoch 389; Elapsed Time = 944s
# 90/97: G=10.980, Dr=0.027, Df=0.024
# Epoch 390; Elapsed Time = 946s
# 90/97: G=11.497, Dr=0.033, Df=0.033
# Epoch 391; Elapsed Time = 949s
# 90/97: G=11.841, Dr=0.030, Df=0.033
# Saving Checkpoint...
# Epoch 392; Elapsed Time = 952s
# 90/97: G=11.344, Dr=0.031, Df=0.030
# Epoch 393; Elapsed Time = 954s
# 90/97: G=11.467, Dr=0.036, Df=0.034
# Epoch 394; Elapsed Time = 956s
# 90/97: G=11.473, Dr=0.028, Df=0.035
# Epoch 395; Elapsed Time = 959s
# 90/97: G=11.554, Dr=0.041, Df=0.033
# Epoch 396; Elapsed Time = 961s
# 90/97: G=11.410, Dr=0.022, Df=0.029
# Epoch 397; Elapsed Time = 964s
# 90/97: G=11.622, Dr=0.028, Df=0.028
# Epoch 398; Elapsed Time = 966s
# 90/97: G=11.272, Dr=0.044, Df=0.045
# Epoch 399; Elapsed Time = 969s
# 90/97: G=10.897, Dr=0.040, Df=0.029
# Epoch 400; Elapsed Time = 971s
# 90/97: G=11.313, Dr=0.014, Df=0.021
# Epoch 401; Elapsed Time = 974s
# 90/97: G=11.902, Dr=0.044, Df=0.036
# Saving Checkpoint...
# Epoch 402; Elapsed Time = 976s
# 90/97: G=11.418, Dr=0.035, Df=0.033
# Epoch 403; Elapsed Time = 979s
# 90/97: G=11.513, Dr=0.045, Df=0.033
# Epoch 404; Elapsed Time = 981s
# 90/97: G=11.888, Dr=0.032, Df=0.036
# Epoch 405; Elapsed Time = 983s
# 90/97: G=11.495, Dr=0.029, Df=0.028
# Epoch 406; Elapsed Time = 986s
# 90/97: G=11.762, Dr=0.033, Df=0.032
# Epoch 407; Elapsed Time = 988s
# 90/97: G=11.781, Dr=0.044, Df=0.043
# Epoch 408; Elapsed Time = 990s
# 90/97: G=11.370, Dr=0.064, Df=0.048
# Epoch 409; Elapsed Time = 993s
# 90/97: G=11.527, Dr=0.034, Df=0.033
# Epoch 410; Elapsed Time = 995s
# 90/97: G=12.005, Dr=0.050, Df=0.041
# Epoch 411; Elapsed Time = 998s
# 90/97: G=11.526, Dr=0.044, Df=0.036
# Saving Checkpoint...
# Epoch 412; Elapsed Time = 1000s
# 90/97: G=11.895, Dr=0.041, Df=0.039
# Epoch 413; Elapsed Time = 1003s
# 90/97: G=11.567, Dr=0.051, Df=0.049
# Epoch 414; Elapsed Time = 1005s
# 90/97: G=11.780, Dr=0.035, Df=0.031
# Epoch 415; Elapsed Time = 1007s
# 90/97: G=12.657, Dr=0.040, Df=0.038
# Epoch 416; Elapsed Time = 1010s
# 90/97: G=11.225, Dr=0.031, Df=0.040
# Epoch 417; Elapsed Time = 1012s
# 90/97: G=11.240, Dr=0.035, Df=0.038
# Epoch 418; Elapsed Time = 1015s
# 90/97: G=11.207, Dr=0.034, Df=0.034
# Epoch 419; Elapsed Time = 1017s
# 90/97: G=11.278, Dr=0.030, Df=0.028
# Epoch 420; Elapsed Time = 1020s
# 90/97: G=11.556, Dr=0.023, Df=0.024
# Epoch 421; Elapsed Time = 1022s
# 90/97: G=11.252, Dr=0.041, Df=0.035
# Saving Checkpoint...
# Epoch 422; Elapsed Time = 1025s
# 90/97: G=11.609, Dr=0.034, Df=0.029
# Epoch 423; Elapsed Time = 1027s
# 90/97: G=10.883, Dr=0.020, Df=0.020
# Epoch 424; Elapsed Time = 1029s
# 90/97: G=11.099, Dr=0.032, Df=0.030
# Epoch 425; Elapsed Time = 1032s
# 90/97: G=11.488, Dr=0.051, Df=0.039
# Epoch 426; Elapsed Time = 1034s
# 90/97: G=10.927, Dr=0.041, Df=0.040
# Epoch 427; Elapsed Time = 1037s
# 90/97: G=10.690, Dr=0.026, Df=0.023
# Epoch 428; Elapsed Time = 1039s
# 90/97: G=11.901, Dr=0.017, Df=0.017
# Epoch 429; Elapsed Time = 1042s
# 90/97: G=11.937, Dr=0.022, Df=0.019
# Epoch 430; Elapsed Time = 1044s
# 90/97: G=11.879, Dr=0.026, Df=0.026
# Epoch 431; Elapsed Time = 1046s
# 90/97: G=11.435, Dr=0.044, Df=0.036
# Saving Checkpoint...
# Epoch 432; Elapsed Time = 1049s
# 90/97: G=11.160, Dr=0.034, Df=0.036
# Epoch 433; Elapsed Time = 1051s
# 90/97: G=11.297, Dr=0.029, Df=0.028
# Epoch 434; Elapsed Time = 1053s
# 90/97: G=11.563, Dr=0.030, Df=0.031
# Epoch 435; Elapsed Time = 1056s
# 90/97: G=11.420, Dr=0.026, Df=0.026
# Epoch 436; Elapsed Time = 1058s
# 90/97: G=12.092, Dr=0.029, Df=0.030
# Epoch 437; Elapsed Time = 1061s
# 90/97: G=12.229, Dr=0.032, Df=0.029
# Epoch 438; Elapsed Time = 1063s
# 90/97: G=11.838, Dr=0.036, Df=0.038
# Epoch 439; Elapsed Time = 1065s
# 90/97: G=11.504, Dr=0.032, Df=0.033
# Epoch 440; Elapsed Time = 1068s
# 90/97: G=12.763, Dr=0.036, Df=0.035
# Epoch 441; Elapsed Time = 1070s
# 90/97: G=12.611, Dr=0.033, Df=0.035
# Saving Checkpoint...
# Epoch 442; Elapsed Time = 1073s
# 90/97: G=12.838, Dr=0.025, Df=0.029
# Epoch 443; Elapsed Time = 1075s
# 90/97: G=10.866, Dr=0.052, Df=0.041
# Epoch 444; Elapsed Time = 1077s
# 90/97: G=11.312, Dr=0.041, Df=0.041
# Epoch 445; Elapsed Time = 1080s
# 90/97: G=11.806, Dr=0.035, Df=0.031
# Epoch 446; Elapsed Time = 1082s
# 90/97: G=11.912, Dr=0.043, Df=0.039
# Epoch 447; Elapsed Time = 1085s
# 90/97: G=11.258, Dr=0.045, Df=0.035
# Epoch 448; Elapsed Time = 1087s
# 90/97: G=11.234, Dr=0.017, Df=0.018
# Epoch 449; Elapsed Time = 1090s
# 90/97: G=11.370, Dr=0.034, Df=0.033
# Epoch 450; Elapsed Time = 1092s
# 90/97: G=10.751, Dr=0.041, Df=0.037
# Epoch 451; Elapsed Time = 1095s
# 90/97: G=11.164, Dr=0.039, Df=0.037
# Saving Checkpoint...
# Epoch 452; Elapsed Time = 1097s
# 90/97: G=11.711, Dr=0.032, Df=0.035
# Epoch 453; Elapsed Time = 1100s
# 90/97: G=11.878, Dr=0.027, Df=0.027
# Epoch 454; Elapsed Time = 1102s
# 90/97: G=11.921, Dr=0.031, Df=0.026
# Epoch 455; Elapsed Time = 1104s
# 90/97: G=11.170, Dr=0.019, Df=0.018
# Epoch 456; Elapsed Time = 1107s
# 90/97: G=12.203, Dr=0.032, Df=0.032
# Epoch 457; Elapsed Time = 1109s
# 90/97: G=12.407, Dr=0.042, Df=0.040
# Epoch 458; Elapsed Time = 1112s
# 90/97: G=11.174, Dr=0.033, Df=0.032
# Epoch 459; Elapsed Time = 1114s
# 90/97: G=10.916, Dr=0.042, Df=0.038
# Epoch 460; Elapsed Time = 1116s
# 90/97: G=11.247, Dr=0.042, Df=0.043
# Epoch 461; Elapsed Time = 1119s
# 90/97: G=11.514, Dr=0.040, Df=0.042
# Saving Checkpoint...
# Epoch 462; Elapsed Time = 1121s
# 90/97: G=11.154, Dr=0.051, Df=0.036
# Epoch 463; Elapsed Time = 1124s
# 90/97: G=10.900, Dr=0.048, Df=0.047
# Epoch 464; Elapsed Time = 1126s
# 90/97: G=11.257, Dr=0.049, Df=0.043
# Epoch 465; Elapsed Time = 1129s
# 90/97: G=11.118, Dr=0.039, Df=0.036
# Epoch 466; Elapsed Time = 1131s
# 90/97: G=10.951, Dr=0.045, Df=0.039
# Epoch 467; Elapsed Time = 1134s
# 90/97: G=11.322, Dr=0.041, Df=0.029
# Epoch 468; Elapsed Time = 1136s
# 90/97: G=10.906, Dr=0.026, Df=0.026
# Epoch 469; Elapsed Time = 1138s
# 90/97: G=11.918, Dr=0.040, Df=0.033
# Epoch 470; Elapsed Time = 1141s
# 90/97: G=11.633, Dr=0.030, Df=0.030
# Epoch 471; Elapsed Time = 1143s
# 90/97: G=11.882, Dr=0.028, Df=0.028
# Saving Checkpoint...
# Epoch 472; Elapsed Time = 1146s
# 90/97: G=12.031, Dr=0.035, Df=0.031
# Epoch 473; Elapsed Time = 1148s
# 90/97: G=12.308, Dr=0.035, Df=0.034
# Epoch 474; Elapsed Time = 1150s
# 90/97: G=12.880, Dr=0.034, Df=0.032
# Epoch 475; Elapsed Time = 1153s
# 90/97: G=13.475, Dr=0.023, Df=0.020
# Epoch 476; Elapsed Time = 1155s
# 90/97: G=12.823, Dr=0.025, Df=0.024
# Epoch 477; Elapsed Time = 1158s
# 90/97: G=12.064, Dr=0.031, Df=0.024
# Epoch 478; Elapsed Time = 1160s
# 90/97: G=11.172, Dr=0.028, Df=0.029
# Epoch 479; Elapsed Time = 1163s
# 90/97: G=11.617, Dr=0.036, Df=0.031
# Epoch 480; Elapsed Time = 1165s
# 90/97: G=11.375, Dr=0.037, Df=0.033
# Epoch 481; Elapsed Time = 1167s
# 90/97: G=11.605, Dr=0.041, Df=0.032
# Saving Checkpoint...
# Epoch 482; Elapsed Time = 1170s
# 90/97: G=11.516, Dr=0.024, Df=0.024
# Epoch 483; Elapsed Time = 1172s
# 90/97: G=11.328, Dr=0.041, Df=0.037
# Epoch 484; Elapsed Time = 1175s
# 90/97: G=11.324, Dr=0.031, Df=0.027
# Epoch 485; Elapsed Time = 1177s
# 90/97: G=11.195, Dr=0.036, Df=0.033
# Epoch 486; Elapsed Time = 1180s
# 90/97: G=11.469, Dr=0.040, Df=0.035
# Epoch 487; Elapsed Time = 1182s
# 90/97: G=11.197, Dr=0.035, Df=0.031
# Epoch 488; Elapsed Time = 1184s
# 90/97: G=11.224, Dr=0.039, Df=0.033
# Epoch 489; Elapsed Time = 1187s
# 90/97: G=10.993, Dr=0.037, Df=0.029
# Epoch 490; Elapsed Time = 1189s
# 90/97: G=11.231, Dr=0.031, Df=0.033
# Epoch 491; Elapsed Time = 1192s
# 90/97: G=11.359, Dr=0.042, Df=0.041
# Saving Checkpoint...
# Epoch 492; Elapsed Time = 1194s
# 90/97: G=10.683, Dr=0.039, Df=0.032
# Epoch 493; Elapsed Time = 1197s
# 90/97: G=11.226, Dr=0.017, Df=0.019
# Epoch 494; Elapsed Time = 1199s
# 90/97: G=11.485, Dr=0.043, Df=0.038
# Epoch 495; Elapsed Time = 1202s
# 90/97: G=10.702, Dr=0.045, Df=0.042
# Epoch 496; Elapsed Time = 1204s
# 90/97: G=11.319, Dr=0.029, Df=0.036
# Epoch 497; Elapsed Time = 1207s
# 90/97: G=10.789, Dr=0.055, Df=0.045
# Epoch 498; Elapsed Time = 1209s
# 90/97: G=11.005, Dr=0.028, Df=0.033
# Epoch 499; Elapsed Time = 1211s
# 90/97: G=11.015, Dr=0.037, Df=0.028
# Epoch 500; Elapsed Time = 1214s
# 90/97: G=10.724, Dr=0.038, Df=0.042

# %%
lt, lv = runGAN(chkpt_name='BTCYourRun', dataset='data/FinancialImages/BW/', epochs=100, use_attn=True, size=32, bw=True)

# %%
lt_df = pd.melt(pd.DataFrame(lt).rename({0:'G',1:'D_R', 2:'D_F'}, axis=1), ignore_index=False).reset_index()
sns.lineplot(data=lt_df, x='index', y='value', hue='variable')
# Out:
# <AxesSubplot:xlabel='index', ylabel='value'>

# %% [markdown]
# ### Similar training pattern to the earlier GAN - but samples still improve with longer training!

# %% [markdown]
# ### Below is an example of a latent vector used to generate one of the images!

# %%
lv[0]
# Out:
# tensor([-1.5540, -0.0504,  1.7159,  1.4659,  2.3626,  0.4135, -0.1917,  0.6918,
#          0.4460,  1.7825,  0.3080, -0.3758, -1.4641,  0.0815,  0.3542, -0.6379])

# %%
# Labels all the generated images according to the same paradigm used to label the real ones
def labelsForGenerated(fileList, folder, threshold=90):
    labels = [1]*len(fileList)
    for i, fileName in enumerate(fileList):
        im = transforms.ToTensor()(Image.open(folder + fileName))
        if im[0,0,0] > im[0,31,31]:
            labels[i] = 0
    return labels

# Interpolate between two arrays
def interpolateArrays(X1, X2, n_steps=10):
    return np.linspace(X1, X2, n_steps)

# %% [markdown]
# ### Here we will explore an important concept: interpolation though the latent space. Basically used to create images that are 'in between' two different samples.

# %%
for j in range(3):
    # Generate some samples from a random latent vector
    lt, lv = runGAN(chkpt_name='BTCDemo', dataset='data/FinancialImages/BW', size=32, bw=True, gen_or_train='gen', use_attn=True, folder_mod='Demo/Random/')
    
    # Label the generated images
    dataDir = 'data/GeneratedImages/Demo/Random/'
    listGen = os.listdir(dataDir)
    labels = labelsForGenerated(listGen, dataDir)
    pd_labels = pd.DataFrame(labels)
    
    # Grab only the samples that are labeled 0 (Negative)
    genNegLabels = pd_labels[pd_labels[0]==0].index.values
    run_label = 'run2'
    
    # Interpolate between these selected images
    for i in range(len(genNegLabels)-2):
        # Interpolate in 16 steps between image i and i+1
        interp = interpolateArrays(lv[genNegLabels[i]], lv[genNegLabels[i+1]], n_steps=16)
        # Interpolate in 16 steps between image i+1 and i+2
        interp2 = interpolateArrays(lv[genNegLabels[i+1]], lv[genNegLabels[i+2]], n_steps=16)
        # Join the two sets of latent vectors into one that is the correct size (32, the batch size)
        interp = torch.cat((torch.tensor(interp), torch.tensor(interp2)))
        # Generate samples relative to this latent vector
        lt1, lv1 =runGAN(chkpt_name='BTCDemo', dataset='data/FinancialImages/', size=32, bw=True, gen_or_train='gen', use_attn=True, latent_vec=interp, folder_mod='Demo/Interp/', gen_name_mod= run_label + '_' + str(i)+ str(j))

# %%
# Put generated data into a dataloader
dataDir = 'data/GeneratedImages/Demo/Interp/'
listGen = os.listdir(dataDir)
setGen_Train = turnToTensors(listGen, dataDir)

targetsGen_Train = torch.FloatTensor(labelsForGenerated(listGen, dataDir))

targetsGen_Train = targetsGen_Train[:, None]
dataGen_Train = torch.utils.data.TensorDataset(setGen_Train, targetsGen_Train)

batchSize = 8

trainLoaderGen = torch.utils.data.DataLoader(dataGen_Train, batch_size = batchSize, shuffle = True)

# %%
# Class distribution of generated data, skewed positive still even though we interpolated
# between negative samples? 
sns.histplot(data=pd.DataFrame(np.array(targetsGen_Train)))
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ### Slight amount of mode collapse - an important concept in GAN training! When a model picks a certain subset of the data and becomes better at training that subset that anything else!
# ![alt text](data/PresentationImages/mode_collapse.jpeg "stonks")

# %%
classifierCNN = CNN()

print("Training the model on generated data:")
print('           -------------------------------------')
print('           -------------------------------------')
fit(classifierCNN, trainLoaderGen, 20)
print('           -------------------------------------')
print('')
print('')


print("Evaluation of model on balanced data:")
print('           -------------------------------------')
evalModel(classifierCNN, testLoaderBal, False)
print('           -------------------------------------')
print('')
print('')

print("Evaluation of model on unbalanced data:")
print('           -------------------------------------')
evalModel(classifierCNN, testLoaderNeg, False)
print('           -------------------------------------')
# Out:
# Training the model on generated data:
#            -------------------------------------
#            -------------------------------------
# Epoch : 0 [0/2496 (0%)]	Loss: 0.682959	 Accuracy:62.500%
# Epoch : 1 [0/2496 (0%)]	Loss: 0.496792	 Accuracy:87.500%
# Epoch : 2 [0/2496 (0%)]	Loss: 0.325373	 Accuracy:87.500%
# Epoch : 3 [0/2496 (0%)]	Loss: 0.561573	 Accuracy:87.500%
# Epoch : 4 [0/2496 (0%)]	Loss: 0.351537	 Accuracy:87.500%
# Epoch : 5 [0/2496 (0%)]	Loss: 0.337916	 Accuracy:100.000%
# Epoch : 6 [0/2496 (0%)]	Loss: 0.385671	 Accuracy:87.500%
# Epoch : 7 [0/2496 (0%)]	Loss: 0.191161	 Accuracy:100.000%
# Epoch : 8 [0/2496 (0%)]	Loss: 0.259052	 Accuracy:100.000%
# Epoch : 9 [0/2496 (0%)]	Loss: 0.145507	 Accuracy:100.000%
# Epoch : 10 [0/2496 (0%)]	Loss: 0.384096	 Accuracy:100.000%
# Epoch : 11 [0/2496 (0%)]	Loss: 0.360333	 Accuracy:87.500%
# Epoch : 12 [0/2496 (0%)]	Loss: 0.303223	 Accuracy:100.000%
# Epoch : 13 [0/2496 (0%)]	Loss: 0.636142	 Accuracy:62.500%
# Epoch : 14 [0/2496 (0%)]	Loss: 0.293442	 Accuracy:100.000%
# Epoch : 15 [0/2496 (0%)]	Loss: 0.436073	 Accuracy:100.000%
# Epoch : 16 [0/2496 (0%)]	Loss: 0.461131	 Accuracy:87.500%
# Epoch : 17 [0/2496 (0%)]	Loss: 0.210746	 Accuracy:100.000%
# Epoch : 18 [0/2496 (0%)]	Loss: 0.325513	 Accuracy:87.500%
# Epoch : 19 [0/2496 (0%)]	Loss: 0.433662	 Accuracy:100.000%
#            -------------------------------------
#
#
# Evaluation of model on balanced data:
#            -------------------------------------
# Test accuracy:  78.333% Avg loss:  0.591
#            -------------------------------------
#
#
# Evaluation of model on unbalanced data:
#            -------------------------------------
# Test accuracy:  81.750% Avg loss:  0.793
#            -------------------------------------

# %%
# Create augmented dataset of fake and real data
setGenNeg = setGen_Train[targetsGen_Train==0]
setGenNeg = setGenNeg[:, None, :, :]
targetsGenNeg = targetsGen_Train[targetsGen_Train==0]
targetsGenNeg = targetsGenNeg[:, None]

setAug_Train = torch.cat((setPos_Train, setGenNeg))
targetsAug_Train = torch.cat((targetsPos_Train, targetsGenNeg))

dataAug_Train = torch.utils.data.TensorDataset(setAug_Train, targetsAug_Train)
trainLoaderAug = torch.utils.data.DataLoader(dataAug_Train, batch_size = batchSize, shuffle = True)

# %%
# Reminder: Real sample here is heavily class imbalanced in favor of the positive class
sns.histplot(data=pd.DataFrame(np.array(targetsPos_Train)))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
# Fake samples here are only negative classes
sns.histplot(data=pd.DataFrame(np.array(targetsGenNeg)))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
# Augmented dataset is roughly balanced
sns.histplot(data=pd.DataFrame(np.array(targetsAug_Train)))
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
classifierCNN = CNN()

print("Training the model on augmented data:")
print('           -------------------------------------')
print('           -------------------------------------')
fit(classifierCNN, trainLoaderAug, 20)
print('           -------------------------------------')
print('')
print('')


print("Evaluation of model on balanced data:")
print('           -------------------------------------')
evalModel(classifierCNN, testLoaderBal, False)
print('           -------------------------------------')
print('')
print('')

print("Evaluation of model on unbalanced data:")
print('           -------------------------------------')
evalModel(classifierCNN, testLoaderNeg, False)
print('           -------------------------------------')
# Out:
# Training the model on augmented data:
#            -------------------------------------
#            -------------------------------------
# Epoch : 0 [0/2083 (0%)]	Loss: 0.690757	 Accuracy:75.000%
# Epoch : 1 [0/2083 (0%)]	Loss: 0.409075	 Accuracy:87.500%
# Epoch : 2 [0/2083 (0%)]	Loss: 0.608113	 Accuracy:100.000%
# Epoch : 3 [0/2083 (0%)]	Loss: 0.523096	 Accuracy:87.500%
# Epoch : 4 [0/2083 (0%)]	Loss: 0.438327	 Accuracy:87.500%
# Epoch : 5 [0/2083 (0%)]	Loss: 0.441481	 Accuracy:100.000%
# Epoch : 6 [0/2083 (0%)]	Loss: 0.270143	 Accuracy:100.000%
# Epoch : 7 [0/2083 (0%)]	Loss: 0.350658	 Accuracy:87.500%
# Epoch : 8 [0/2083 (0%)]	Loss: 0.267496	 Accuracy:100.000%
# Epoch : 9 [0/2083 (0%)]	Loss: 0.132430	 Accuracy:100.000%
# Epoch : 10 [0/2083 (0%)]	Loss: 0.524219	 Accuracy:100.000%
# Epoch : 11 [0/2083 (0%)]	Loss: 0.262351	 Accuracy:100.000%
# Epoch : 12 [0/2083 (0%)]	Loss: 0.433373	 Accuracy:100.000%
# Epoch : 13 [0/2083 (0%)]	Loss: 0.190469	 Accuracy:87.500%
# Epoch : 14 [0/2083 (0%)]	Loss: 0.361293	 Accuracy:75.000%
# Epoch : 15 [0/2083 (0%)]	Loss: 0.461663	 Accuracy:100.000%
# Epoch : 16 [0/2083 (0%)]	Loss: 0.340676	 Accuracy:87.500%
# Epoch : 17 [0/2083 (0%)]	Loss: 0.433719	 Accuracy:100.000%
# Epoch : 18 [0/2083 (0%)]	Loss: 0.519870	 Accuracy:87.500%
# Epoch : 19 [0/2083 (0%)]	Loss: 0.265683	 Accuracy:100.000%
#            -------------------------------------
#
#
# Evaluation of model on balanced data:
#            -------------------------------------
# Test accuracy:  85.833% Avg loss:  0.788
#            -------------------------------------
#
#
# Evaluation of model on unbalanced data:
#            -------------------------------------
# Test accuracy:  82.250% Avg loss:  1.167
#            -------------------------------------

# %% [markdown]
# ## Here we are able to improve the model performance on both the balanced and unbalanced real data! Cool!

# %% [markdown]
# ## This approach can be applied across many domains, and may even help you with your dataset problems!

# %% [markdown]
# # Thanks for listening!

# %% [markdown]
# ![alt text](data/PresentationImages/GANMeme.jpg "stonks")
